# %%
# !pip uninstall tensorflow-probability -y
# !pip install fastapi==0.100.1
# !pip install gradio==4.5.0
# !pip install PyMuPDF transformers[sentencepiece] langchain
# !pip install typing-extensions==4.6.0
# Out:
# WARNING: Skipping tensorflow-probability as it is not installed.
# Requirement already satisfied: fastapi==0.100.1 in /usr/local/lib/python3.10/dist-packages (0.100.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from fastapi==0.100.1) (2.5.3)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /usr/local/lib/python3.10/dist-packages (from fastapi==0.100.1) (0.27.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from fastapi==0.100.1) (4.5.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,<3.0.0,>=1.7.4->fastapi==0.100.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,<3.0.0,>=1.7.4->fastapi==0.100.1) (2.14.6)
# Collecting typing-extensions>=4.5.0 (from fastapi==0.100.1)
#   Using cached typing_extensions-4.9.0-py3-none-any.whl (32 kB)
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from starlette<0.28.0,>=0.27.0->fastapi==0.100.1) (3.7.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi==0.100.1) (3.6)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi==0.100.1) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi==0.100.1) (1.2.0)
# Installing collected packages: typing-extensions
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires kaleido, which is not installed.
# Successfully installed typing-extensions-4.9.0
# Requirement already satisfied: gradio==4.5.0 in /usr/local/lib/python3.10/dist-packages (4.5.0)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.5.0) (23.2.1)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.5.0) (4.2.2)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.10/dist-packages (from gradio==4.5.0) (0.100.1)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.10/dist-packages (from gradio==4.5.0) (0.3.1)
# Requirement already satisfied: gradio-client==0.7.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.5.0) (0.7.0)
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/dist-packages (from gradio==4.5.0) (0.26.0)
# Requirement already satisfied: huggingface-hub>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.5.0) (0.20.1)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /usr/local/lib/python3.10/dist-packages (from gradio==4.5.0) (6.1.1)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.5.0) (3.1.2)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.5.0) (2.1.3)
# Requirement already satisfied: matplotlib~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.5.0) (3.7.1)
# Requirement already satisfied: numpy~=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.5.0) (1.23.5)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.5.0) (3.9.10)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from gradio==4.5.0) (23.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.5.0) (1.5.3)
# Requirement already satisfied: pillow<11.0,>=8.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.5.0) (9.4.0)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.5.0) (2.5.3)
# Requirement already satisfied: pydub in /usr/local/lib/python3.10/dist-packages (from gradio==4.5.0) (0.25.1)
# Requirement already satisfied: python-multipart in /usr/local/lib/python3.10/dist-packages (from gradio==4.5.0) (0.0.6)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.5.0) (6.0.1)
# Requirement already satisfied: requests~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.5.0) (2.31.0)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.5.0) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.5.0) (0.12.0)
# Requirement already satisfied: typer[all]<1.0,>=0.9 in /usr/local/lib/python3.10/dist-packages (from gradio==4.5.0) (0.9.0)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.5.0) (4.9.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.5.0) (0.25.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from gradio-client==0.7.0->gradio==4.5.0) (2023.6.0)
# Requirement already satisfied: websockets<12.0,>=10.0 in /usr/local/lib/python3.10/dist-packages (from gradio-client==0.7.0->gradio==4.5.0) (11.0.3)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio==4.5.0) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio==4.5.0) (4.19.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio==4.5.0) (0.12.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.14.0->gradio==4.5.0) (3.13.1)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.14.0->gradio==4.5.0) (4.66.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==4.5.0) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==4.5.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==4.5.0) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==4.5.0) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==4.5.0) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==4.5.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio==4.5.0) (2023.3.post1)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio==4.5.0) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio==4.5.0) (2.14.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests~=2.0->gradio==4.5.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests~=2.0->gradio==4.5.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests~=2.0->gradio==4.5.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests~=2.0->gradio==4.5.0) (2023.11.17)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer[all]<1.0,>=0.9->gradio==4.5.0) (8.1.7)
# Requirement already satisfied: colorama<0.5.0,>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from typer[all]<1.0,>=0.9->gradio==4.5.0) (0.4.6)
# Requirement already satisfied: shellingham<2.0.0,>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer[all]<1.0,>=0.9->gradio==4.5.0) (1.5.4)
# Requirement already satisfied: rich<14.0.0,>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer[all]<1.0,>=0.9->gradio==4.5.0) (13.7.0)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.10/dist-packages (from uvicorn>=0.14.0->gradio==4.5.0) (0.14.0)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /usr/local/lib/python3.10/dist-packages (from fastapi->gradio==4.5.0) (0.27.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->gradio==4.5.0) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx->gradio==4.5.0) (1.0.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->gradio==4.5.0) (1.3.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.5.0) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.5.0) (2023.11.2)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.5.0) (0.32.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.5.0) (0.15.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio==4.5.0) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio==4.5.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio==4.5.0) (2.16.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->gradio==4.5.0) (1.2.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio==4.5.0) (0.1.2)
# Requirement already satisfied: PyMuPDF in /usr/local/lib/python3.10/dist-packages (1.23.8)
# Requirement already satisfied: transformers[sentencepiece] in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: langchain in /usr/local/lib/python3.10/dist-packages (0.1.0)
# Requirement already satisfied: PyMuPDFb==1.23.7 in /usr/local/lib/python3.10/dist-packages (from PyMuPDF) (1.23.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (0.20.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (4.66.1)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (0.1.99)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (3.20.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.23)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.9.1)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.6.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.33)
# Requirement already satisfied: langchain-community<0.1,>=0.0.9 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.0.11)
# Requirement already satisfied: langchain-core<0.2,>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.1.9)
# Requirement already satisfied: langsmith<0.1.0,>=0.0.77 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.0.79)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.5.3)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (8.2.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (3.20.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers[sentencepiece]) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers[sentencepiece]) (4.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain) (2.4)
# Requirement already satisfied: anyio<5,>=3 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.2,>=0.1.7->langchain) (3.7.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (2.14.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[sentencepiece]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[sentencepiece]) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[sentencepiece]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[sentencepiece]) (2023.11.17)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.2)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3->langchain-core<0.2,>=0.1.7->langchain) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3->langchain-core<0.2,>=0.1.7->langchain) (1.2.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain) (1.0.0)
# Collecting typing-extensions==4.6.0
#   Downloading typing_extensions-4.6.0-py3-none-any.whl (30 kB)
# Installing collected packages: typing-extensions
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.9.0
#     Uninstalling typing_extensions-4.9.0:
#       Successfully uninstalled typing_extensions-4.9.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires kaleido, which is not installed.
# pydantic 2.5.3 requires typing-extensions>=4.6.1, but you have typing-extensions 4.6.0 which is incompatible.
# Successfully installed typing-extensions-4.6.0

# %%
import gradio

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Function: Fileload

# %%
def keep_text_until_pattern(text, pattern):
    # Case-insensitive search for the pattern
    index = text.lower().find(pattern.lower())

    # Check if the pattern is found
    if index != -1:
        # Keep the text until the pattern
        kept_text = text[:index]
        return kept_text
    else:
        # Return the original text if the pattern is not found
        return text

# %%
from google.colab import auth
auth.authenticate_user()  # Authenticate with Google Cloud

from google.cloud import storage
import pandas as pd
import io
import json
import yaml
import fitz
import codecs
import re

## File loading
class FileLoader:
    def __init__(self, bucket_name):
        # Authenticate with Google Cloud
        auth.authenticate_user()

        self.bucket_name = bucket_name

        # Initialize a client to access Google Cloud Storage
        self.storage_client = storage.Client()

        # Get the bucket and blob (object)
        self.bucket = self.storage_client.bucket(bucket_name)

    def save_json_in_gcs(self, data, file_path):

        blob = self.bucket.blob(file_path)

        # Convert the list to a JSON string
        json_data = json.dumps(data)

        # Upload the JSON data to the blob
        blob.upload_from_string(json_data)


    def load_json_from_gcs(self, file_path):

        blob = self.bucket.blob(file_path)

        # Download the JSON data from the blob
        json_data = blob.download_as_text()

        # Parse the JSON data into a Python list
        data_list = json.loads(json_data)
        return data_list

    def load_df_from_gcs(self, file_path, header = 0):

        blob = self.bucket.blob(file_path)
        content = blob.download_as_text(encoding='latin1')

        # Convert the string content to bytes
        content_bytes = content.encode('latin1')

        # Create a DataFrame from the Excel content
        df = pd.read_excel(io.BytesIO(content_bytes), header = header)
        return df

    def load_csv_from_gcs(self, file_path):

        blob = self.bucket.blob(file_path)
        content = blob.download_as_text(encoding='latin1')

        # Convert the string content to bytes
        content_bytes = content.encode('latin1')

        # Create a DataFrame from the Excel content
        df = pd.read_csv(io.BytesIO(content_bytes))
        return df

    def save_df_to_gcs(self, df, file_path):

        # Convert DataFrame to CSV string
        csv_string = df.to_csv(index=False)

        # Upload the CSV string to the blob
        blob = self.bucket.blob(file_path)
        blob.upload_from_string(csv_string, 'text/csv')

    def read_pdf_from_gcs(self, file_name, exclude_strings):
        print(f"Processing: {file_name}")
        blob = self.bucket.blob(file_name)
        pdf_content = blob.download_as_bytes()

        doc = fitz.open(stream=pdf_content, filetype="pdf")
        concatenated_text = []
        important_text = ""
        length = 0
        num_pages = 0
        for page_num in range(doc.page_count):
            if page_num >=2:
                page = doc.load_page(page_num)
                page_text = page.get_text()
                num_pages += 1
                # Check if any of the exclude_strings are present on the page
                if (re.search(re.compile(r'note(s)?\s*to\s*(the)?\s*financial\s*statement(s)?', re.IGNORECASE), page_text)) and ("activit" in page_text.lower()):
                    if not re.compile(r'^content\(s\)[ \t\n\r]+$').findall(page_text):
                        page_text = keep_text_until_pattern(page_text, "significant accounting")
                        important_text = important_text + "/n/n/n"+  page_text
                        #length+=len(page_text)
                        continue
                if any(exclude_str in page_text.lower() for exclude_str in exclude_strings):
                    if "activit" not in page_text.lower():
                        continue  # Skip this page if any exclude_string is found
                concatenated_text.append(page_text)
        #print(f"Average length of a page is : {length/num_pages}")
        doc.close()
        if len(important_text) >= 8000:
            important_text = important_text[:8000]
        return '\n'.join(concatenated_text), important_text

    def read_yaml_from_gcs(self, file_name):
        blob = self.bucket.blob(file_name)

        # Download the YAML content as bytes
        yaml_bytes = blob.download_as_bytes()

        # Load the YAML content as a dictionary
        yaml_dict = yaml.safe_load(yaml_bytes)

        return yaml_dict

    def save_dict_to_yaml_gcs(self, file_name, data):
        # Convert dictionary to YAML format
        yaml_data = yaml.dump(data, default_flow_style=False)

        # Create blob (file) in the bucket
        blob = self.bucket.blob(file_name)

        # Upload YAML data to the blob
        blob.upload_from_string(yaml_data)

    def load_embeddings(self, source_blob_name, model):
        # Get the blob and download the embeddings
        blob = storage.Blob(source_blob_name, self.storage_client.get_bucket(self.bucket_name))
        embeddings_bytes = blob.download_as_bytes()

        # Convert the bytes back to a NumPy array
        embeddings_np = np.frombuffer(embeddings_bytes, dtype=np.float32)

        # Assuming that embeddings are in the float32 format, adjust the data type accordingly
        # embeddings_np = np.frombuffer(embeddings_bytes, dtype=np.float64)  # for float64

        # Convert the NumPy array to a PyTorch tensor
        tensor = torch.from_numpy(embeddings_np)
        if (len(tensor.shape) == 1) and (model == "textembedding-gecko"):
            tensor = tensor.reshape(-1, 768)
        elif len(tensor.shape) == 1:
            tensor = tensor.reshape((-1,1024))

        return tensor

    def list_files(self,directory_path):
        blobs = self.storage_client.list_blobs(self.bucket_name, prefix = directory_path)
        files = [blob.name for blob in blobs]
        return files

# %% [markdown]
# # Function: Encoder

# %%
from google.colab import auth
auth.authenticate_user()  # Authenticate with Google Cloud

from google.cloud import storage
from transformers import AutoTokenizer, AutoModel
import torch
import numpy as np
from tqdm import tqdm
import os
import tempfile
import math
import time

class TextEmbedder:
    def __init__(self, model_name, project_id, bucket_name, from_local = False, model_location = None, tokenizer_location = None):
        self.project_id = project_id
        self.model_location = model_location
        self.tokenizer_location = tokenizer_location
        self.bucket_name = bucket_name
        self.client = storage.Client(project=self.project_id)
        self.model_name = model_name

        if model_name == "textembedding-gecko":
            from vertexai.preview.language_models import TextEmbeddingModel
            self.model = TextEmbeddingModel.from_pretrained(model_name)
        else:
            if from_local:
                self.download_directory_from_gcs(model_location, './model')
                self.download_directory_from_gcs(tokenizer_location, './tokenizer')
                self.model = AutoModel.from_pretrained('./model')
                self.tokenizer = AutoTokenizer.from_pretrained('./tokenizer')
                print("Embedding Model Loaded")
            else:
                # Load model

                self.tokenizer = AutoTokenizer.from_pretrained(model_name)
                self.model = AutoModel.from_pretrained(self.model_name)

                # Save the model and tokenizer locally
                self.model.save_pretrained('./model')
                self.tokenizer.save_pretrained('./tokenizer')
                self.upload_directory_to_gcs('./model', model_location)
                self.upload_directory_to_gcs('./tokenizer', tokenizer_location)

    def download_directory_from_gcs(self, source_directory_name, destination_directory_name):
        """Downloads a directory from the bucket."""
        # Get the GCS bucket
        bucket = self.client.get_bucket(self.bucket_name)

        # List all files in the specified folder
        blobs = bucket.list_blobs(prefix=source_directory_name)

        # Create a temporary folder in Colab
        os.makedirs(destination_directory_name, exist_ok=True)

        # Copy files from GCS to the temporary folder in Colab
        for blob in blobs:
            if not blob.name.endswith('/'):
                destination_blob_pathname = os.path.join(destination_directory_name, os.path.basename(blob.name))
                blob.download_to_filename(destination_blob_pathname)

    def upload_directory_to_gcs(self, source_directory_name, destination_blob_name):
        """Uploads a directory to the bucket."""
        bucket = self.client.get_bucket(self.bucket_name)
        for root, dirs, files in os.walk(source_directory_name):
            for filename in files:
                blob = bucket.blob(os.path.join(destination_blob_name, filename))
                blob.upload_from_filename(os.path.join(root, filename))

    def _average_pool(self, last_hidden_states, attention_mask):
        last_hidden = last_hidden_states.masked_fill(~attention_mask[..., None].bool(), 0.0)
        return last_hidden.sum(dim=1) / attention_mask.sum(dim=1)[..., None]

    def encode_text(self, input_texts, batch_size):
        if self.model_name == "textembedding-gecko":
            # Note only 5 items, and limited tokens
            batch_size = 3
            self.embeddings = torch.Tensor([])
            num_batches = math.ceil(len(input_texts) / batch_size)
            for i in range(num_batches):
                batch_texts = input_texts[i*batch_size:min((i+1)*batch_size, len(input_texts))]
                embeddings = self.model.get_embeddings(batch_texts)
                self.embeddings = torch.cat((self.embeddings, torch.stack([torch.tensor(inner_list.values) for inner_list in embeddings])))
                time.sleep(2.0 + np.random.uniform(0.1, 1.00))
            return self.embeddings
        else:
            # Tokenize the input texts
            embeddings = []

            # Get the total number of input texts
            total_texts = len(input_texts)

            with tqdm(total=total_texts, desc="Embedding Progress") as pbar:
                with torch.no_grad():
                    for i in range(0, len(input_texts), batch_size):
                        batch_dict = self.tokenizer(input_texts[i:i+batch_size], max_length=1024, padding=True, truncation=True, return_tensors='pt')
                        input_chunk = batch_dict['input_ids']
                        mask_chunk = batch_dict['attention_mask']
                        outputs = self.model(input_ids=input_chunk, attention_mask=mask_chunk)
                        chunk_embeddings = self._average_pool(outputs.last_hidden_state, mask_chunk)
                        embeddings.append(chunk_embeddings)
                        pbar.update(batch_size)

            # Concatenate embeddings from all batches
            embeddings = torch.cat(embeddings, dim=0)
            self.embeddings = embeddings
            return embeddings

    def save_embeddings(self, bucket_name, file_name):
        """Save the embeddings to a Google Cloud Storage bucket."""

        # Convert the embeddings to a NumPy array
        embeddings_np = self.embeddings.detach().numpy()

        # Convert the NumPy array to bytes
        embeddings_bytes = embeddings_np.tobytes()

        # Initialize the Google Cloud Storage client
        storage_client = storage.Client(project=self.project_id)

        # Get the bucket
        bucket = storage_client.get_bucket(bucket_name)

        # Create a new blob and upload the embeddings
        blob = storage.Blob(file_name, bucket)
        blob.upload_from_string(embeddings_bytes)

        print(f'Embeddings uploaded to gs://{bucket_name}/{file_name}')

# %% [markdown]
# # Function: Sim Search

# %%
## Similarity search class
import numpy as np

class SimSearch:
    """Search for similar documents in a corpus."""
    def __init__(self, elbow_method = False, k=5, min_k = 3, max_k = 7):
        self.elbow_method = elbow_method
        self.k = k
        self.min_k = min_k
        self.max_k = max_k

    def sim_score(self, vec1, vec2):
        if len(vec1.shape) == 1:
            # If vec1 is a single vector, reshape it to (1, 1024)
            vec1 = vec1.reshape(1, -1)
        if len(vec2.shape) == 1:
            # If vec2 is a single vector, reshape it to (1, 1024)
            vec2 = vec2.reshape(1, -1)

        x, _ = vec1.shape
        y, _ = vec2.shape

        similarity_matrix = np.zeros((x, y))

        for i in range(x):
            for j in range(y):
                dot_product = np.dot(vec1[i], vec2[j])
                norm_vec1 = np.linalg.norm(vec1[i])
                norm_vec2 = np.linalg.norm(vec2[j])

                similarity_matrix[i][j] = dot_product / (norm_vec1 * norm_vec2)
        return similarity_matrix

    def best_k(self, sorted_scores):
        # Calculate differences between consecutive elements
        differences = [sorted_scores[i] - sorted_scores[i + 1] for i in range(len(sorted_scores) - 1)]

        # Find the index of the maximum difference
        sharp_drop_index = differences.index(max(differences))

        # Corresponding k value
        k_value = sharp_drop_index + 1
        return k_value

    def search_k_sim(self, vec1, vec2):
        # Calculate similarity scores
        similarity_matrix = self.sim_score(vec1, vec2).reshape(-1)
        sorted_scores = np.sort(-similarity_matrix)*-1.0
        if self.elbow_method:
            k_value = self.best_k(sorted_scores)
            k_value = max(min(self.max_k, k_value), self.min_k)
        else:
            k_value = self.k

        # Sort the similarity scores in descending order
        sorted_indices = np.argsort(-similarity_matrix)[:k_value]
        sorted_scores = sorted_scores[:k_value]

        return sorted_indices, sorted_scores

# %% [markdown]
# # Function: FS Summarizer

# %%
# User LLM for Summarization

import time
import vertexai
#from vertexai.preview.language_models import TextGenerationModel
from vertexai.preview.generative_models import GenerativeModel, ChatSession

from vertexai.preview.generative_models import (
    HarmCategory,
    HarmBlockThreshold )
from google.cloud.aiplatform_v1beta1.types.content import SafetySetting

from langchain.text_splitter import RecursiveCharacterTextSplitter
import numpy as np

class FsSummarizer:
    def __init__(self,
                 project_id,
                 model_name,
                 max_decode_steps,
                 temperature,
                 top_p,
                 top_k,
                 chunk_size,
                 chunk_overlap,
                 text_embedder,
                 activity_embedding,
                 k_sim,
                 location= "asia-southeast1",
                 ):
        self.project_id = project_id
        self.model_name = model_name
        self.temperature = temperature
        self.max_decode_steps = max_decode_steps
        self.top_p = top_p
        self.top_k = top_k
        vertexai.init(project=project_id, location=location)

        self.text_splitter = RecursiveCharacterTextSplitter(
            chunk_size=chunk_size,
            chunk_overlap=chunk_overlap,
            length_function=len
            )
        self.text_embedder = text_embedder
        self.sim_searcher = SimSearch(elbow_method = False, k = k_sim)
        self.activity_embedding = activity_embedding


    def chunk(self, text):
        chunks = self.text_splitter.split_text(text=text)
        return chunks

    def summarize(self, desc) :
        model = GenerativeModel("gemini-pro")
        #chat = model.start_chat()
        """Summarize using a Large Language Model."""

        prompt = f'''
        The description of the whole group of the main or parent company, the Company, extracted from its annual statement, which may include its subsidiaries and operations is as follows:
        ```
        {desc}
        ```

        Extract the main activity of the main or parent company (not the whole group, nor its subsidiaries), excluding any discontinued operations, joint ventures and subsidiaries, from the above description of the company.
        During the extraction, you must step by step think and strictly follow the following rules:
        - Parent / main company is the company which holds all the subsidiaries, joint ventures and operations.
        - Ignore all activities in the subsidiaries, joint ventures and discontinued operations. Do not output these activities.
        - If the main or parent company's primary activity is solely holding  or 'investment holding', the primary activity is a holding or 'investment holding'.
        - If the main or parent company's primary activity is holding company or 'investment holding' with provision of management services, the primary activity is a holding company/investment holding.
        - If there are other primary activities besides holding or 'investment holding' (other than provision of management services) for the main or parent company ( excluding all its subsidiaries and joint ventures), identify the other activities as primary activities
        - If multiple primary activities are stated, you must strictly choose only one major activity of the main/parent company (not its subsidiaries, nor the whole group). For example, for 'financing business and provision of corporate advisory services' is considered as two activities; Choose the dominant activity.
        - If the primary activity identified above is not holding or 'investment holding', explain succinctly this primary activity, with examples of goods and services if possible, in two short sentences.
        - If the primary activity identified above is holding or 'investment holding', do not provide examples or explanation.

        For example, if the primary activity of the main or parent company is both 'investment holding' and 'hotel management', only output the 'hotel management' portion.
        If the primary activity of the main or parent company is 'holding' and its subsidiary is 'mining', output 'holding company'.
        If the primary activity of the main or parent company is 'holding' and its joint venture is 'manufacturing', output 'holding company'.

        You must then look through all the activities extracted, and output the main primary activity (excluding subsidiaries and joint ventures) according to the description.
        Output concisely with elaboration. Your output must consider but not elaborate on the rules above.
        '''
        #model = TextGenerationModel.from_pretrained(self.model_name)
        """
        response = model.predict(
            prompt,
            temperature=self.temperature,
            max_output_tokens=self.max_decode_steps,
            top_k=self.top_k,
            top_p=self.top_p
            )
        """
        response = model.generate_content(
            prompt,
            generation_config={
                "max_output_tokens": 2048,
                "temperature": self.temperature,
                "top_p": self.top_p,
            }
        )
        safety_settings = [
            SafetySetting(
                category=HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT,
                threshold=HarmBlockThreshold.BLOCK_NONE,
            )
        ]
        time.sleep(2.0 + np.random.uniform(0.1, 0.2))
        if response:
            try:
                return response.text.replace('main or parent', '').replace('main', '').replace('parent', '').replace('  ', ' ').strip()
            except:
                return desc

    def run_summarizer(self, text, important_text, batch_size):
        chunks = self.chunk(text)

        if len(important_text) < 2000:
            start_time = time.time()
            print('Embed Chunks...')
            chunk_embedding = self.text_embedder.encode_text(chunks, batch_size)
            print(f'...in {np.round(time.time()-start_time,3)}s')

            print("Searching relevant sections...")
            sorted_indices, _ = self.sim_searcher.search_k_sim(self.activity_embedding, chunk_embedding)

            print("Chunking financial statements...")
            relevant_chunks_list = [chunks[i] for i in sorted_indices]
            relevant_chunks = ' '.join(relevant_chunks_list)
            if len(important_text)>0:
                relevant_chunks = important_text + relevant_chunks
        else:
            relevant_chunks = important_text
        print("Calling LLM to summarize pdf...")
        summarized_desc = self.summarize(relevant_chunks)

        return relevant_chunks, summarized_desc

    def explain(self, desc, summary):
        model = GenerativeModel("gemini-pro")
        chat = model.start_chat()
        """Perform explanaiton of summary using a Large Language Model."""
        prompt = f'''
        The description of the company is as follows:
        ```
        {desc}
        ```

        The primary activity extracted is as follows: {summary}

        Extract the relevant sentences or paragraphs from the description of the company which is relevant to the primary activity extracted.
        Pick at least 3 sentences or paragraphs and as many as possible.
        '''

        """
        model = TextGenerationModel.from_pretrained(self.model_name)

        response = model.predict(
            prompt,
            temperature=self.temperature,
            max_output_tokens=self.max_decode_steps,
            top_k=self.top_k,
            top_p=self.top_p
            )
        """
        try:
            response = chat.send_message(prompt)
            time.sleep(2.0 + np.random.uniform(0.1, 0.2))
            return response.text
        except:
            return ''

# %% [markdown]
# # Function: Classification Using Prompt

# %%
## Using Palm2 for classification
import vertexai
#from vertexai.preview.language_models import TextGenerationModel
from vertexai.preview.generative_models import GenerativeModel, ChatSession

import re
from transformers import pipeline
import torch

class Classifier:
    def __init__(self, project_id, model_name, max_decode_steps, temperature, top_p, top_k, location= "asia-southeast1"):
        self.project_id = project_id
        self.model_name = model_name

        if self.model_name in ("text-bison", "text-bison-001"):
            self.temperature = temperature
            self.max_decode_steps = max_decode_steps
            self.top_p = top_p
            self.top_k = top_k
            vertexai.init(project=project_id, location=location)

        else:
            self.model = pipeline("zero-shot-classification", model=self.model_name)

    def identify_holding(self, description):
        model = GenerativeModel("gemini-pro")
        chat = model.start_chat()
        prompt = f'''
        This is a description of the company:
        ```
        {description}
        ```

        Is the primary, principle or main activities of the company is solely a holding or 'investment holding', without any other activities in non-subsidiaries operations (except provision of management services)? Evaluate based on all the details (not just one sentence) in the description.
        You must consider the following when answering the question:
        - Ignore all activities in the subsidiaries and discontinued operations.
        - Holding or 'investment holding' companies of a group of subsidiary corporations and whose principal activity is owning the group. The holding companies in this Sub-class generally do not provide any other service to the businesses in which the equity is held, i.e. they do not administer or manage other units.
        - Holding or 'investment holding' companies own other companies. Those owning or investing in other assets like properties are not holding companies.
        - The company is a holding only if the description involves holding or 'investment holding', and does not contain any other activities (except management services and investment trading).
        - If the main/parent company's description depicts solely a holding or 'investment holding' company with no other activities (except provision of management services and investment trading), the primary activity is a holding company/investment holding.
        - If there are other types of activities besides holding or 'investment holding' (other than provision of management services), the company is strictly not a holding company.
        - The following companies (not exhaustive list) are not holding or 'investment holding' companies even if one of their primary activities is also holding/holding investment companies (this list is not exhaustive):
            - Hotel or hotel management
            - Real estate
            - Bank
            - Funds
            - Finance companies
            - Property investment
        - For example, if the company's description is "The company is an investment holding company. The company is a manufacturing company", the company is not a holding company.

        Do not explain.
        '''
        """
        model = TextGenerationModel.from_pretrained(self.model_name)
        response = model.predict(
            prompt,
            temperature=self.temperature,
            max_output_tokens=self.max_decode_steps,
            top_k=self.top_k,
            top_p=self.top_p,)
        """
        response = chat.send_message(prompt)
        response = response.text.strip()
        response = response[:min(len(response), 3)].lower()

        if response=="yes":
            time.sleep(8.0 + np.random.uniform(0.1, 1.00))
            return "Other holding companies"

    def classify(self, description, categories, categories_desc= '', others_condition = '') :
        """Predict using a Large Language Model."""
        categories = [item for item in categories if 'holding' not in item.lower()]
        model = GenerativeModel("gemini-pro")
        #chat = model.start_chat()
        if self.model_name in ("text-bison", "text-bison-001", "gemini-pro"):
            all_cat = "\n".join(categories)

            prompt = f'''
            This is a description of the company:
            ```
            {description}
            ```
            Classify the primary activity of the company into one of the following `category`, each separated by a line break:
            ```
            {all_cat}
            ```

            You must consider the definition of the category when making the classification:
            ```
            {categories_desc}
            ```

            You must follow these rules when making the classification:
            - You must pick the most dominant primary activity of the company for classification and rely on the definition of the category to make the classification
            - Ignore all information about the company's subsidiaries and discontinued operations in the description.
            - If the primary activity of the company focuses on tradinig or sales, and not focused on manufactuing, then the output `category` must not be related to manufacturing or milling.
            - If the company's primary activity is not only a holding company or not only an investment holding, strictly do not choose any options regarding holding companies, or Bank/Financial holding companies.
            {others_condition}
            - Double check to ensure that the output is in the `category` above.
            Strictly output one `category` from above, without any explanation or preambles.
            '''
            """
            model = TextGenerationModel.from_pretrained(self.model_name)
            response = model.predict(
                prompt,
                temperature=self.temperature,
                max_output_tokens=self.max_decode_steps,
                top_k=self.top_k,
                top_p=self.top_p
                )
            """
            #response = chat.send_message(prompt)
            try:
                response = model.generate_content(
                    prompt,
                    generation_config={
                        "temperature": self.temperature,
                        "top_p": self.top_p,
                    }
                )
                safety_settings = [
                    SafetySetting(
                        category=HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT,
                        threshold=HarmBlockThreshold.BLOCK_NONE,
                    )
                ]
                time.sleep(10.0 + np.random.uniform(0.1, 1.00))
                return response.text.strip()
            except:
                return ""
        else:

            output = self.model(description, categories, multi_label=False)
            return output['labels'][np.argmax(output['scores'])], np.max(output['scores'])


    def compare(self, description, pred, pred_others, cat_desc):
        """Predict using a Large Language Model."""
        if self.model_name in ("text-bison", "text-bison-001", "gemini-pro"):
            if ('n.e.c' in pred_others.lower()) or ('not elsewhere classified' in pred_others.lower()):
                prompt = f'''This is a description of the company:
                ```
                {description}
                ```

                Determine if the following is a good label for the primary activity of the company: {pred}
                You must follow these rules when seleting the choices:
                - If the company's primary activity is not only a holding company or not only an investment holding, the the labels regarding holding companies, or bank/holding company is not suitable.

                Output Yes or No only, without preamble or explanation.
                '''
                model = GenerativeModel("gemini-pro")
                chat = model.start_chat()
                response = chat.send_message(prompt)

                """
                model = TextGenerationModel.from_pretrained(self.model_name)
                response = model.predict(
                    prompt,
                    temperature=self.temperature,
                    max_output_tokens=self.max_decode_steps,
                    top_k=self.top_k,
                    top_p=self.top_p,)
                """
                response = response.text.strip()
                if response=="Yes":
                    return pred
                elif response == "No":
                    return pred_others

            prompt = f'''This is a description of the company:
            ```
            {description}
            ```

            Select from one of the choices below to label the primary activity of the company using the description above.
            Choice 1: ``` {pred}```

            Choice 2: ```{pred_others}```

            While selecting the choices, consider the description of each choice:
            ```{cat_desc}```

            You must follow these rules when seleting the choices:
            - If the company's is primarily a financing company, then select the choice 'Finance companies (with deposit taking functions)'.
            Strictly output without any explanation or preambles.
            '''
            model = GenerativeModel("gemini-pro")
            chat = model.start_chat()
            response = chat.send_message(prompt)
            """
            model = TextGenerationModel.from_pretrained(self.model_name)
            response = model.predict(
                prompt,
                temperature=self.temperature,
                max_output_tokens=self.max_decode_steps,
                top_k=self.top_k,
                top_p=self.top_p,)
            """

            cleaned_text = re.sub(r'\d\.', '', response.text).strip()
            cleaned_text = re.sub(r'Choice \d\.', '', cleaned_text).strip()
            return cleaned_text
        else:
            output = self.model(description, [pred, pred_others], multi_label=False)
            return output['labels'][np.argmax(output['scores'])]

# %% [markdown]
# # Function: Evaluator

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.preprocessing import LabelEncoder

class Evaluator:
    def __init__(self, label, predicted):
        """IMPORTANT: there must be the same number of files in the label csv and number of pdf files"""
        self.evaluate_df = pd.concat([predicted, label], axis=1)
        #self.evaluate_df["SSIC Code"] = self.evaluate_df["SSIC Code"].astype(str)
        #self.evaluate_df["SSIC Code (Predicted)"] = self.evaluate_df["SSIC Code (Predicted)"].astype(str)
        all_classes = set(self.evaluate_df["SSIC Code"].values).union(set(self.evaluate_df["SSIC Code (Predicted)"].values))
        self.label_encoder = LabelEncoder()
        self.label_encoder.fit(list(all_classes))

    def evaluate(self):

        ground_truth = self.label_encoder.transform(self.evaluate_df["SSIC Code"]).tolist()
        predicted_labels = self.label_encoder.transform(self.evaluate_df["SSIC Code (Predicted)"]).tolist()
        accuracy = accuracy_score(ground_truth, predicted_labels)
        precision = precision_score(ground_truth, predicted_labels, average='micro')
        recall = recall_score(ground_truth, predicted_labels, average='micro')
        f1 = f1_score(ground_truth, predicted_labels, average='micro')

        return self.evaluate_df, accuracy, precision, recall, f1

# %% [markdown]
# # Full Pipeline

# %%
# Define Full Pipeline for mulitple files

def classify_one_company(fileloader,
                         file_name,
                         summarizer,
                         batch_size,
                         classifier,
                         activity_embedding):
    # Summarize FS
    ## Read FS
    exclude_strings = [
        'auditor',
        "director",
        "accounting policies",
        "corporate governance",
        "lease liabilities",
        "sustainability",
        "consolidated statement of cash flows",
        "financial risk",
        "dividend"
        ]

    fs, important_text = fileloader.read_pdf_from_gcs(file_name, exclude_strings)
    ## Perform Summary
    relevant_chunks, summarized_desc = summarizer.run_summarizer(fs, important_text, batch_size)
    summary_explanation = summarizer.explain(summarized_desc, relevant_chunks)

    print("Summary extracted: ", summarized_desc)
    ## Perform Classification
    ssic_code, ssic_label, model_score = classifier.classify(summarized_desc)
    return ssic_code, ssic_label, summarized_desc, summary_explanation, model_score

# %%
def classify_from_gcs(bucket_name):
    # Load configs

    fileloader = FileLoader(bucket_name)
    config = fileloader.read_yaml_from_gcs("config.yaml")

    project_id = config["project_id"]
    #others_score_threshold = config["others_score_threshold"]
    text_embedding_model_name =  config["text_embedding_model_name"]
    classifier_model_name = config["classifier_model_name"]
    summarizer_model_name = config["summarizer_model_name"]
    google_model_name = config["google_model_name"]

    batch_size = config["batch_size"]

    # Load directories
    model_location = config["dir"]["model_location"]
    tokenizer_location = config["dir"]["tokenizer_location"]
    ssic_df_fp = config["dir"]["ssic_df_fp"]
    l3_list_fp = config["dir"]["l3_list_fp"]
    l3_list_others_fp = config["dir"]["l3_list_others_fp"]
    activity_embedding_fp = config["dir"]["activity_embedding_fp"]
    l2_l3_embeddings_fp = config["dir"]["l2_l3_embeddings_fp"]
    l2_l3_embeddings_others_fp = config["dir"]["l2_l3_embeddings_others_fp"]
    fs_dir = config["dir"]["fs_dir"]
    output_fp = config["dir"]["output_fp"]
    label_fp = config["dir"]["label_fp"]
    evaluator_fp = config["dir"]["evaluator_fp"]

    # Load artifacts
    ssic_df = fileloader.load_df_from_gcs(ssic_df_fp, header = config['columns']["header_row"])
    l3_desc_list = fileloader.load_json_from_gcs(l3_list_fp)
    l3_desc_list_others = fileloader.load_json_from_gcs(l3_list_others_fp)
    l2_l3_embeddings = fileloader.load_embeddings(l2_l3_embeddings_fp, text_embedding_model_name)
    l2_l3_embeddings_others = fileloader.load_embeddings(l2_l3_embeddings_others_fp, text_embedding_model_name)
    activity_embedding = fileloader.load_embeddings(activity_embedding_fp, text_embedding_model_name)
    label = fileloader.load_csv_from_gcs(label_fp)

    assert len(l3_desc_list) == len(l2_l3_embeddings), print(f"Embeddings (non-others) {len(l2_l3_embeddings)} are not the same length as the list {len(l3_desc_list)}")
    assert len(l3_desc_list_others) == len(l2_l3_embeddings_others), print(f"Embeddings {len(l2_l3_embeddings_others)} are not the same length as the list {len(l3_desc_list_others)}")

    # Load classes
    text_embedder = TextEmbedder(text_embedding_model_name,
                                  from_local = True,
                                  project_id=project_id,
                                  bucket_name=bucket_name,
                                  model_location = model_location,
                                  tokenizer_location = tokenizer_location)

    summarizer = FsSummarizer(
        project_id,
        summarizer_model_name,
        max_decode_steps = 256,
        temperature = 0.0,
        top_p = 1.0,
        top_k = 10,
        chunk_size = 1000,
        chunk_overlap = 50,
        text_embedder= text_embedder,
        activity_embedding= activity_embedding,
        k_sim = 5,
        location= "asia-southeast1"
        )

    classifier_google = Classifier(project_id,
                            google_model_name,
                            max_decode_steps = 256,
                            temperature =0.0,
                            top_p = 1.0,
                            top_k = 10,
                            location= "asia-southeast1"
                            )

    classifier = Classifier(project_id,
                            classifier_model_name,
                            max_decode_steps = 256,
                            temperature =0.0,
                            top_p = 1.0,
                            top_k = 10,
                            location= "asia-southeast1"
                            )

    ssic_classifier = SSICClassifier(
        classifier_google,
        classifier,
        ssic_df,
        text_embedder,
        #others_score_threshold,
        l3_desc_list,
        l3_desc_list_others,
        l2_l3_embeddings,
        l2_l3_embeddings_others,
        config
        )
    # Loops through all files in directory
    all_fs = fileloader.list_files(fs_dir)

    assert (len(all_fs)-1) == len(label), print(f"You must have same number of companies in the fs folder ({len(all_fs)-1}) as in the  Company SSIC Code.csv ({len(label)})")

    ssic_labels = pd.DataFrame()

    for file_name in all_fs:
        if file_name.endswith(".pdf"):

            ssic_code, ssic_label, summarized_desc, summary_explanation, model_score = classify_one_company(
                fileloader,
                file_name,
                summarizer,
                batch_size,
                ssic_classifier,
                activity_embedding
                )
            company = file_name.split(".")[0].split('/')[-1]
            new_label =  pd.DataFrame(
                {
                    "Company": [company],
                    "SSIC Title (Predicted)": [ssic_label],
                    "SSIC Code (Predicted)": [ssic_code],
                    "Explanation": [summary_explanation],
                    "Model Score": [model_score]
                    }
                )

            ssic_labels = pd.concat([ssic_labels, new_label])

    ssic_labels = ssic_labels.reset_index(drop=True)
    fileloader.save_df_to_gcs(ssic_labels, output_fp)

    if config["evaluation_mode"] is not None:
        # Calculate metrics
        evaluator = Evaluator(ssic_labels, label)

        summary_df, acc, pre, recall, f1 = evaluator.evaluate()
        print(f"Accuracy: {acc}")

        # Save concat dataframe
        fileloader.save_df_to_gcs(summary_df, evaluator_fp)
        return summary_df
    else:
        return ssic_labels

# %%
import time

class SSICClassifier:
    def __init__(self,
                 classifier_google,
                 classifier,
                 ssic_df,
                 text_embedder,
                 l3_desc_list,
                 l3_desc_list_others,
                 l2_l3_embeddings,
                 l2_l3_embeddings_others,
                 config):
        print("Intializing SSIC Classifier.")
        # Intialize Search
        #self.searcher = SimSearch(elbow_method = True, min_k = 4, max_k = 7)
        self.searcher = SimSearch(elbow_method = False, k=10)
        self.classifier_google = classifier_google
        self.classifier = classifier

        # DataFrame
        self.ssic_df = ssic_df

        # L3 List
        self.l3_desc_list = l3_desc_list
        self.l3_desc_list_others = l3_desc_list_others

        # Embeddings
        self.text_embedder = text_embedder
        self.l2_l3_embeddings = l2_l3_embeddings
        self.l2_l3_embeddings_others = l2_l3_embeddings_others

        # Description
        self.l3_desc_list = l3_desc_list
        self.l3_desc_list_others = l3_desc_list_others

        # Others
        self.config = config

    def search(self, encoded_desc, non_others=True):
        if non_others:
            embeddings = self.l2_l3_embeddings_others
            desc_list = self.l3_desc_list_others
        else:
            embeddings = self.l2_l3_embeddings
            desc_list = self.l3_desc_list

        sorted_indices, scores = self.searcher.search_k_sim(encoded_desc, embeddings)

        rel_l3 = [desc_list[i] for i in sorted_indices]
        return rel_l3

    def produce_desc(self, rel_l):
        cat_dict = self.ssic_df[self.ssic_df['SSIC 2020 Title'].isin(rel_l)].set_index('SSIC 2020 Title')['Detailed Definitions'].to_dict()
        cat_desc = "\n\n\n".join(f"{key}: {value}" for key, value in cat_dict.items())
        return cat_desc

    def get_codes(self, df_cat, l3_cat_final):
        label_line = df_cat[(df_cat[self.config['columns']['ssic_desc']].str.contains(l3_cat_final))|(df_cat[self.config['columns']['ssic_desc']]==l3_cat_final)]
        label_cat = label_line[self.config['columns']['ssic_desc']]
        #print(label_line, label_cat, l3_cat_final)
        if type(label_cat) != str:
            if len(label_cat)>0:
                label_cat = label_cat.iloc[0]
        label_code = label_line[self.config['columns']['ssic_code']]
        if type(label_code) != str:
            if len(label_code)>0:
                label_code = label_code.iloc[0]
        return label_code, label_cat

    def classify(self, summaried_desc):
        """Full pipeline for classification"""

        # If holding company, return holding
        label_holdings = self.classifier_google.identify_holding(summaried_desc)

        if label_holdings:
            label_code, label_cat =  self.get_codes(self.ssic_df, label_holdings)
            return label_code, label_cat, None

        # Encode description
        # For non-holding companies
        l3_exist = False
        l3_exist_others = False

        encoded_desc = self.text_embedder.encode_text([summaried_desc], 1)

        # Search for L2+L3 SSIC
        rel_l3 = self.search(encoded_desc, False)
        print("Initial search: ", rel_l3)

        # Get Description for l3
        cat_desc = self.produce_desc(rel_l3)

        # Perform classification with Palm2
        l3_cat = self.classifier.classify(summaried_desc, rel_l3, cat_desc)
        if type(l3_cat) == tuple:
            l3_cat, l3_score = l3_cat
        else:
            l3_score = None

        # Perform Search for Others
        rel_l3_others = self.search(encoded_desc, True)
        print("Initial search others: ", rel_l3_others)

        # Produce Description
        cat_desc_others = self.produce_desc(rel_l3_others)
        # Classify with Palm 2

        l3_cat_others = self.classifier.classify(summaried_desc, rel_l3_others, cat_desc_others)
        if type(l3_cat_others) == tuple:
            l3_cat_others, l3_score_others = l3_cat_others
        else:
            l3_score_others = None

        # Check existence
        if l3_cat in self.l3_desc_list:
            l3_exist = True
        if l3_cat_others in self.l3_desc_list_others:
            l3_exist_others = True

        # Perform comparison
        desc= self.produce_desc([l3_cat,l3_cat_others])
        l3_cat_final = self.classifier.compare(summaried_desc, l3_cat, l3_cat_others, desc)

        # Double Check LLM's response
        if (l3_cat_final == l3_cat) and l3_exist:
            df_cat = self.ssic_df[self.ssic_df[self.config['columns']['ssic_desc']].isin(self.l3_desc_list)]
            l3_score_final = l3_score
        elif (l3_cat_final == l3_cat_others) and l3_exist_others:
            df_cat = self.ssic_df[self.ssic_df[self.config['columns']['ssic_desc']].isin(self.l3_desc_list_others)]
            l3_score_final = l3_score_others
        elif l3_exist:
            l3_cat_final = l3_cat
            l3_score_final = l3_score
            df_cat = self.ssic_df[self.ssic_df[self.config['columns']['ssic_desc']].isin(self.l3_desc_list)]
        elif l3_exist_others:
            l3_cat_final = l3_cat_others
            l3_score_final = l3_score_others
            df_cat = self.ssic_df[self.ssic_df[self.config['columns']['ssic_desc']].isin(self.l3_desc_list_others)]

        print(f"Final label: {l3_cat_final}, selected from {l3_cat}, {l3_cat_others}")

        if l3_exist_others or l3_exist:
            label_code, label_cat =  self.get_codes(df_cat, l3_cat_final)
            return label_code, label_cat, l3_score_final
        else:
            return None, None, None

# %%
bucket_name = "acra-ssic-classification"
classify_from_gcs(bucket_name)
# Out:
# Intializing SSIC Classifier.
# Processing: data/fs/ABR HOLDINGS LIMITED 2022.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  - Manufacture of ice cream
# - Operation of Swensen’s ice cream parlours cum restaurants
# - Operation of other specialty restaurants
# Initial search:  ['Manufacture of ice-cream', 'Wholesale of ice-cream', 'Manufacture of condensed and evaporated milk (including pasteurising and bottling of fluid milk)', 'Retail sale of confectionery and bakery products (not manufactured on site)', 'Manufacture of chocolate and chocolate products', 'Wholesale of confectionery and bakery products', 'Manufacture of bread, cakes and confectionery (excluding frozen bakery products)', 'Refrigerated warehousing and storage', 'Manufacture of biscuits (including wafers and cones)', 'Manufacture of non-chocolate confectionery (e.g. sweets, toffees, crystallised fruits, chewing gums)']
# Initial search others:  ['Manufacture of ice except dry ice', 'Manufacture and repair of refrigerating, air-conditioning and ventilating machinery and equipment except household refrigerators', 'Manufacture of dairy products n.e.c. (e.g. butter, cheese, ice-cream mixes and powder, yoghurt)', 'Manufacture of cordials, syrups and composite concentrates for beverages', 'Manufacture of bakery products n.e.c.', 'Manufacture of other food products n.e.c. (except food chemicals and additives)', 'Manufacture of sauces including soya bean sauce (e.g. tomato sauce, chilli sauce)', 'Wholesale of commercial food service equipment (e.g. hotel kitchen equipment)', 'Manufacture of soya bean products except soya bean sauce and soya bean milk', 'Manufacture of vegetable and animal oils and fats n.e.c.']
# Final label: Manufacture of ice-cream, selected from Manufacture of ice-cream, Manufacture of dairy products n.e.c. (e.g. butter, cheese, ice-cream mixes and powder, yoghurt)
# Processing: data/fs/ABUNDANCE INTERNATIONAL LIMITED 2022.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  The activity of the company is print and paper management related activities.
# Initial search:  ['Wholesale of paper and paper products', 'Wholesale of stationery', 'Manufacture of printers', 'Colour separation', 'Manufacture of containers and boxes of paper and paperboard', 'Printing of continuous and fan-fold forms', 'Manufacture of pulp, paper and paperboard', 'Printing of newspapers', 'Commercial printing (e.g. printing of brochures, cards, envelopes, labels and stationery)', 'Printing of periodicals, books and magazines']
# Initial search others:  ['Printing n.e.c.', 'Manufacture of sanitary towels, toilet paper, paper towels, disposable diapers and related paper products', 'Wholesale of paper, paper and cellophane products and stationery n.e.c.', 'Service activities related to printing n.e.c. (including plate-making)', 'Manufacture of cards, envelopes and stationery, unprinted', 'Manufacture of paper cups, plates and utensils', 'Manufacture of other articles of paper and paperboard n.e.c. (e.g. papier mache, wallpaper)', 'Manufacture of joss paper and other related ceremonial paper products (including effigies and other funeral paper goods and Chinese lanterns)', 'Wholesale of office machines and equipment (including accessories)', 'Other specialised office support activities n.e.c.']
# Final label: Commercial printing (e.g. printing of brochures, cards, envelopes, labels and stationery), selected from Commercial printing (e.g. printing of brochures, cards, envelopes, labels and stationery), Service activities related to printing n.e.c. (including plate-making)
# Processing: data/fs/ABUNDANTE LIMITED 2023.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  - The activity of the company is an investment holding company.
# - The company does not have any other primary activities besides holding or 'investment holding'.
# Processing: data/fs/ACCRELIST LTD. 2023.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  Investment holding.
# Processing: data/fs/ACESIAN PARTNERS LIMITED 2022.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  The activity of the company is the design, manufacture and supply of critical airflow and related products.
#
# Examples of critical airflow and related products include air ducts, fans, and filters.
# Initial search:  ['Supply of air or water for cooling or heating purposes', 'Wholesale of lifts, escalators and industrial and office air-conditioning equipment', 'Manufacture and repair of pumps (e.g. hydraulic pumps, drainage pumps)', 'Manufacture of metal doors, window and door frames, grilles and gratings', 'Manufacture of electric power cables and wires', 'Manufacture of window and door screens and shades', 'Manufacture and repair of taps, cocks and valves', 'Collection, purification and distribution of water (including desalination of water)', 'Manufacture of industrial gases and dry ice', 'Manufacture and repair of heating boilers, radiators and correctors (including parts)']
# Initial search others:  ['Manufacture and repair of refrigerating, air-conditioning and ventilating machinery and equipment except household refrigerators', 'Manufacture and repair of separation/mixing equipment (e.g. filters, separators, mixers)', 'Manufacture of metal precision components', 'Manufacture and repair of pumps, compressors, taps and valves n.e.c.', 'Manufacture of plumbing, heating and related products (including parts) except electric', 'Manufacture and repair of water/waste water treatment equipment', 'Manufacture of pipe fittings', 'Wholesale of household electrical appliances and equipment (including household air-conditioners)', 'Manufacture of capacitors', 'Manufacture of laminboard, particle board and other panels and boards n.e.c.']
# Final label: Manufacture and repair of refrigerating, air-conditioning and ventilating machinery and equipment except household refrigerators, selected from Supply of air or water for cooling or heating purposes, Manufacture and repair of refrigerating, air-conditioning and ventilating machinery and equipment except household refrigerators
# Processing: data/fs/ACMA LTD. 2022.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  The activity of the company is investment holding.
# Processing: data/fs/ADVANCED SYSTEMS AUTOMATION LIMITED 2022.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  - Investment holding
#
# The company's primary activity is investment holding.
# Processing: data/fs/ANNAIK LIMITED 2022.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  The activity of the company is investment holding.
# Processing: data/fs/AP OIL INTERNATIONAL LIMITED 2022.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  The activity of the company is an investment holding company.
# Processing: data/fs/ASIA-PACIFIC STRATEGIC INVESTMENTS LIMITED 2023.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  The activity of the company is investment holding.
# Processing: data/fs/ASIAN MICRO HOLDINGS LIMITED 2023.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  - The primary activity of the company is investment holding.
# - The company does not have any other primary activities besides investment holding.
# Processing: data/fs/ASL MARINE HOLDINGS LTD. 2023.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  - The activity of the company is investment holding.
# - The company does not have any other primary activities besides holding or 'investment holding'.
# Processing: data/fs/ASPEN (GROUP) HOLDINGS LIMITED 2023.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  - The primary activity of the company is investment holding.
# - The company does not have any other primary activities besides investment holding.
#
# Therefore, the primary activity of the company is investment holding.
# Processing: data/fs/AVI-TECH HOLDINGS LIMITED 2023.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  The activity of the company is investment holding.
# Processing: data/fs/BEST WORLD INTERNATIONAL LIMITED 2022.pdf
# Embed Chunks...
# ...in 172.379s
# Searching relevant sections...
# Chunking financial statements...
# Calling LLM to summarize pdf...
# Summary extracted:  The activity of the company is not specified in the provided description.
# Initial search:  ['Manufacture of Traditional Chinese Medicine', 'Operating of serviced apartments', 'Manufacture of prepared animal feeds (including additives for animal feed)', 'Botanical and zoological gardens and nature reserves activities', 'Letting of self-owned or leased real estate property except food courts, coffee shops and canteens (e.g. office/exhibition space, shopping mall, self-storage facilities)', 'Manufacture of blank magnetic tapes, diskettes, Blu-ray technology discs, CDs, DVDs and VCDs', 'Chalets', 'Manufacture and assembly of bicycles, tricycles, trishaws and invalid carriages (including parts and accessories)', 'Manufacture of additives for mineral oil (e.g. lubricant and fuel additives)', 'Manufacture of bearings (including disc and ball bearings)']
# Initial search others:  ['Translation services', 'Charitable and other supporting activities aimed at humanitarian work', 'Production of advertisements, corporate videos and event videos', 'Manufacture of pesticides and other agro-chemical products (including insecticides, herbicides and disinfectants)', 'Manufacture of water treatment, waste treatment and oilfield chemicals', 'Movie, video, television and other programme production activities n.e.c.', 'Manufacture of catalysts and catalyst regeneration', 'Residential (other than town councils), commercial and industrial real estate management', 'Manufacture of photographic film, paper, plate and chemicals', 'Activities of religious organisations n.e.c.']
# Final label: Manufacture of Traditional Chinese Medicine, selected from Manufacture of Traditional Chinese Medicine, Translation services
# Processing: data/fs/BRC ASIA LIMITED 2022.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  - Prefabrication of steel reinforcement for use in concrete
# - Trading of steel reinforcing bars
# - Manufacturing and sale of wire mesh fences
#
# Main primary activity: Manufacturing and trading of steel products
# Initial search:  ['Manufacture of steel structural component', 'Manufacture of metal doors, window and door frames, grilles and gratings', 'Wholesale of metals and metal ores (e.g. steel pipes) except general hardware', 'Manufacture of metal strips and slabs (e.g. awnings)', 'Iron and steel foundries', 'Manufacture of ferrous metal alloys', 'Iron and steel rolling mills', 'Manufacture of metal pipes and tubes', 'Manufacture of ready-mix concrete', 'Iron and steel and non-ferrous forgings']
# Initial search others:  ['Production of pre-cast components', 'Manufacture of structural metal products n.e.c. (e.g. metal sections, corrugated sheets)', 'Manufacture of kitchen and household utensils (e.g. steel shelf, showcase counters, kitchen trolleys display racks, sink bowls and other customised kitchen equipment)', 'Manufacture of basic iron and steel n.e.c. (including smelting)', 'Manufacture of articles of concrete, cement and plaster n.e.c. (except precast concrete components)', 'Manufacture of non-structural pre-cast components (e.g. lightweight partitions, secondary roof slabs)', 'Slitting, shearing and pasting of metal sheeting', 'Manufacture of pipe fittings', 'Manufacture of metal wire and cable products n.e.c.', 'Manufacture and repair of welding and soldering equipment (including arc welding electrodes)']
# Final label: Manufacture of structural metal products n.e.c. (e.g. metal sections, corrugated sheets), selected from Manufacture of steel structural component, Manufacture of structural metal products n.e.c. (e.g. metal sections, corrugated sheets)
# Processing: data/fs/BRITISH AND MALAYAN HOLDINGS LIMITED 2023.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  The activity of the company is investment holding.
# Processing: data/fs/CAMSING HEALTHCARE LIMITED 2023.pdf
# Embed Chunks...
# ...in 166.978s
# Searching relevant sections...
# Chunking financial statements...
# Calling LLM to summarize pdf...
# Summary extracted:  The description does not provide information about the activity of the company, excluding any discontinued operations, joint ventures and subsidiaries.
# Initial search:  ['Bank/Financial holding companies (including insurance holding company)', 'Casinos', 'Manufacture of Traditional Chinese Medicine', 'Manufacture of prepared animal feeds (including additives for animal feed)', 'Manufacture of biscuits (including wafers and cones)', 'Chalets', 'Nursing and personal care facilities (including nursing homes and hospices)', 'Traditional/Long-only asset/Portfolio management', 'Operating of serviced apartments', 'Manufacture of condensed and evaporated milk (including pasteurising and bottling of fluid milk)']
# Initial search others:  ['Other holding companies', 'Other information service activities n.e.c.', 'Manufacture of refined petroleum products n.e.c.', 'Corporate finance advisory services', 'Manufacture of water treatment, waste treatment and oilfield chemicals', 'Other financial service activities, except insurance and pension funding activities n.e.c.', 'Movie, video, television and other programme distribution activities n.e.c.', 'Trustee, fiduciary and custody services firms (including nominee companies, trustees and REIT trustees)', 'Other amusement and recreation activities n.e.c. (including recreation parks/beaches and recreational fishing)', 'Movie, video, television and other programme production activities n.e.c.']
# Final label: Other information service activities n.e.c., selected from Manufacture of condensed and evaporated milk (including pasteurising and bottling of fluid milk), Other information service activities n.e.c.
# Processing: data/fs/CASA HOLDINGS LIMITED 2022.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  - Investment holding company.
# Processing: data/fs/CH OFFSHORE LTD. 2022.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  Investment holding.
# Processing: data/fs/CHEMICAL INDUSTRIES (FAR EAST) LIMITED. 2023.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  The activity of the company is investment holding.
# Processing: data/fs/CHINA AVIATION OIL (SINGAPORE) CORPORATION LTD 2022.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  The activity of the company is trading and supply of jet fuel and trading of other petroleum products.
#
# Examples of goods and services: jet fuel, other petroleum products
# Initial search:  ['Wholesale of fuels and related products', 'Manufacture of petroleum lubricating oil', 'Retail sale of automotive fuel (e.g. petrol kiosks, CNG refilling stations)', 'Airport operation services', 'Crude petroleum and natural gas production', 'Manufacture of additives for mineral oil (e.g. lubricant and fuel additives)', 'Ship bunkering', 'Service activities incidental to oil and gas extraction (excluding surveying and engineering design and consultancy services supporting mining, oil and gas extraction and offshore exploration activities)', 'Petroleum refineries', 'Wholesale of petrochemical products']
# Initial search others:  ['Manufacture of refined petroleum products n.e.c.', 'Other related services (e.g. arranging for sale of natural gas)', 'Retail sale of liquefied petroleum gas (LPG)', 'Manufacture of biofuels', 'Corporate finance advisory services', 'Manufacture of vegetable and animal oils and fats n.e.c.', 'Renting of industrial machinery and equipment', 'Translation services', 'Security dealings and commodity contracts brokerage activities n.e.c.', 'Representative offices of foreign banks']
# Final label: Wholesale of fuels and related products, selected from Wholesale of fuels and related products, Other related services (e.g. arranging for sale of natural gas)
# Processing: data/fs/CHUAN HUP HOLDINGS LIMITED 2023.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  - Investment holding
# - Investment trading
# - Provision of management services
# Initial search:  ['Traditional/Long-only asset/Portfolio management', 'Property fund management (including REIT management and direct property fund management)', 'Single/Multiple family offices activities (e.g. managing investments and trusts for a single or multiple families)', 'Stock, share and bond brokers and dealers', 'Collective portfolio investment funds with rental income', 'Bank/Financial holding companies (including insurance holding company)', 'Manufacture of bearings (including disc and ball bearings)', 'Operating of serviced apartments', 'Letting of self-owned or leased real estate property except food courts, coffee shops and canteens (e.g. office/exhibition space, shopping mall, self-storage facilities)', 'Management consultancy services']
# Initial search others:  ['Residential (other than town councils), commercial and industrial real estate management', 'Fund management activities n.e.c.', 'Activities auxiliary to fund management activities (e.g. independent fund administration firms)', 'Other financial service activities, except insurance and pension funding activities n.e.c.', 'Transaction/Payment processing services', 'Trustee, fiduciary and custody services firms (including nominee companies, trustees and REIT trustees)', 'Security dealings and commodity contracts brokerage activities n.e.c.', 'Treasury centres', 'Corporate finance advisory services', 'Other holding companies']
# Final label: Other financial service activities, except insurance and pension funding activities n.e.c., selected from Investment holding, Other financial service activities, except insurance and pension funding activities n.e.c.
# Processing: data/fs/CITY DEVELOPMENTS LIMITED 2022.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  - Property developer and owner
#
# - The company's primary activity is developing and owning properties.
# Initial search:  ['Real estate developers', 'Operating of serviced apartments', 'Letting of self-owned or leased real estate property except food courts, coffee shops and canteens (e.g. office/exhibition space, shopping mall, self-storage facilities)', 'Property fund management (including REIT management and direct property fund management)', 'Collective portfolio investment funds with rental income', 'Real estate agencies and valuation services', 'Letting and operating of self-owned or leased food courts, coffee shops and canteens (with mainly rental income)', 'Management of self-owned strata titled property (i.e. Management Corporation Strata Title)', 'Bank/Financial holding companies (including insurance holding company)', 'General contractors (building construction including major upgrading works)']
# Initial search others:  ['Other holding companies', 'Residential (other than town councils), commercial and industrial real estate management', 'Real estate activities on a fee or commission basis n.e.c. (excluding online marketplaces)', 'Manufacture of pesticides and other agro-chemical products (including insecticides, herbicides and disinfectants)', 'Renting and leasing of furniture, utensils and electronic equipment for household use', 'Renting and leasing of other personal and household goods n.e.c. (excluding online marketplaces)', 'Production of advertisements, corporate videos and event videos', 'Manufacture of laminboard, particle board and other panels and boards n.e.c.', 'Production of pre-cast components', 'Manufacture of sanitary towels, toilet paper, paper towels, disposable diapers and related paper products']
# Final label: Real estate developers, selected from Real estate developers, Residential (other than town councils), commercial and industrial real estate management
# Processing: data/fs/CORTINA HOLDINGS LIMITED 2023.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  - The activity of the company is an investment holding company.
# - The company provides management services to its subsidiaries and associates.
# Processing: data/fs/CREATIVE TECHNOLOGY LTD. 2023.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  - Design, manufacture and distribution of digitised sound and video boards, computers and related multimedia and personal digital entertainment products.
#
# - The primary activity of the company is the design, manufacture and distribution of electronic products, such as sound and video boards, computers, and multimedia and personal digital entertainment products.
# Initial search:  ['Manufacture of consumer electronics', 'Retail sale of audio and video equipment (e.g. radio and television sets, sound reproducing and recording equipment)', 'Manufacture of computers and data processing equipment except computer peripheral equipment', 'Repair of audio and video equipment (e.g. television sets, speakers and DVD players)', 'Manufacture of smart cards and related products (e.g. smart card readers)', 'Manufacture of disk drives (including CD-ROM drives, DVD-ROM drives, optical drives, flash drives, tape drives, solid state drives, storage subsystems)', 'Manufacture of electronic security systems (including electronic sensors, burglar and fire alarm systems)', 'Manufacture of blank magnetic tapes, diskettes, Blu-ray technology discs, CDs, DVDs and VCDs', 'Manufacture of discrete devices (e.g. diodes, light-emitting diodes, transistors and rectifiers)', 'Wholesale of computer accessories (e.g. memory cards, computer cables)']
# Initial search others:  ['Manufacture of other electronic components and boards n.e.c.', 'Manufacture of printed circuit boards with electronic parts', 'Wholesale of audio and video equipment except electrical and electronic components (e.g. radio and television sets, sound reproducing and recording equipment)', 'Manufacture of printed circuit boards without electronic parts', 'Manufacture of laminboard, particle board and other panels and boards n.e.c.', 'Manufacture of electronic display devices except light emitting diodes', 'Manufacture of semiconductor devices n.e.c.', 'Renting and leasing of professional radio and television sets and sound reproducing and recording equipment', 'Production of advertisements, corporate videos and event videos', 'Manufacture of computers and peripheral equipment n.e.c.']
# Final label: Manufacture of consumer electronics, selected from Manufacture of consumer electronics, Manufacture of computers and peripheral equipment n.e.c.
# Processing: data/fs/CSE GLOBAL LIMITED 2022.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  The activity of the company is the provision of total integrated industrial automation, information technology and intelligent transport solutions.
#
# Examples of goods and services provided by the company include:
# - Industrial automation systems
# - Information technology solutions
# - Intelligent transport solutions
# Initial search:  ['Manufacture of electronic security systems (including electronic sensors, burglar and fire alarm systems)', 'Information technology consultancy (except cybersecurity)', 'Manufacture and repair of industrial robots (including Automated Guided Vehicles (AGVs))', 'Transport-related industrial design services', 'Manufacture of parts and accessories for motor vehicles (e.g. engine parts, brakes, clutches, axles, gear boxes)', 'Manufacture of bearings (including disc and ball bearings)', 'Computer facilities management activities', 'Repair and maintenance of motor vehicles (including installation of parts & accessories)', 'Manufacture and repair of railway and tramway locomotives and rolling stock (including specialised parts except engines, electric motors and signalling equipment)', 'Manufacture and assembly of motor vehicles']
# Initial search others:  ['Manufacture of other transport equipment n.e.c. (e.g. carts, wagons)', 'Manufacture and repair of electric motors, generators, transformers and electricity distribution and control apparatus n.e.c. (e.g. busbar trunking)', 'Manufacture of industrial and mechanical rubber goods', 'Manufacture of pesticides and other agro-chemical products (including insecticides, herbicides and disinfectants)', 'Manufacture and repair of lifting and handling equipment n.e.c. (including conveying systems and industrial automated systems)', 'Renting of industrial machinery and equipment', 'Manufacture and repair of refrigerating, air-conditioning and ventilating machinery and equipment except household refrigerators', 'Agrotechnology consultancy services', 'Manufacture and repair of packaging machinery', 'Manufacture and repair of separation/mixing equipment (e.g. filters, separators, mixers)']
# Final label: Manufacture and repair of lifting and handling equipment n.e.c. (including conveying systems and industrial automated systems), selected from Information technology consultancy (except cybersecurity), Manufacture and repair of lifting and handling equipment n.e.c. (including conveying systems and industrial automated systems)
# Processing: data/fs/DATAPULSE TECHNOLOGY LIMITED 2023.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  Investment holding
# Processing: data/fs/DELFI LIMITED 2022.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  The activity of the company is investment holding.
# Processing: data/fs/ENGRO CORPORATION LIMITED 2022.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  - Manufacture and sale of building materials
# - Investment holding
# Initial search:  ['Wholesale of structural clay and concrete products (e.g. mosaic tiles, bricks)', 'Manufacture of ready-mix concrete', 'Manufacture of steel structural component', 'Wholesale of paints (including varnishes and supplies)', 'Manufacture of metal doors, window and door frames, grilles and gratings', 'Manufacture of cement, lime and plaster', 'Manufacture of bearings (including disc and ball bearings)', 'Manufacture of bricks', 'Manufacture of plastic tableware, household and kitchen ware (excluding disposable utensils)', 'Wholesale of logs, sawn timber, plywood and related products']
# Initial search others:  ['Manufacture of articles of concrete, cement and plaster n.e.c. (except precast concrete components)', 'Manufacture of non-structural pre-cast components (e.g. lightweight partitions, secondary roof slabs)', 'Wholesale of construction materials, hardware, plumbing and heating equipment and supplies n.e.c. (e.g. cement, sand)', 'Manufacture of laminboard, particle board and other panels and boards n.e.c.', 'Production of pre-cast components', 'Building construction n.e.c.', 'Manufacture of paints, varnishes and similar coatings and mastics n.e.c.', 'Manufacture of wooden window, door and other millwork, except prefabricated wooden building structures', 'Manufacture and repair of machinery for mining, quarrying and construction n.e.c.', 'Other holding companies']
# Final label: Manufacture of cement, lime and plaster, selected from Manufacture of cement, lime and plaster, Manufacture of articles of concrete, cement and plaster n.e.c. (except precast concrete components)
# Processing: data/fs/F J BENJAMIN HOLDINGS LTD 2023.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  The activity of the company is investment holding and the provision of management services to its subsidiaries.
# Processing: data/fs/FAR EAST GROUP LIMITED 2022.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  - Manufacturing and trading of refrigeration parts
# - Servicing of cold rooms
# - Construction and installation of commercial and industrial cold rooms
# Initial search:  ['Refrigerated warehousing and storage', 'Supply of air or water for cooling or heating purposes', 'Wholesale of lifts, escalators and industrial and office air-conditioning equipment', 'Manufacture of ice-cream', 'Manufacture of plastic bottles, boxes and containers (except for household use)', 'Wholesale of motor vehicles except motorcycles and scooters', 'Manufacture and repair of tanks, reservoirs and containers of metal (e.g. metal cylinders, storage vessels and containers for compressed or liquefied gas)', 'Manufacture and repair of taps, cocks and valves', 'Manufacture and repair of pumps (e.g. hydraulic pumps, drainage pumps)', 'Manufacture of metal doors, window and door frames, grilles and gratings']
# Initial search others:  ['Manufacture and repair of refrigerating, air-conditioning and ventilating machinery and equipment except household refrigerators', 'Wholesale of commercial food service equipment (e.g. hotel kitchen equipment)', 'Manufacture of ice except dry ice', 'Wholesale of household electrical appliances and equipment (including household air-conditioners)', 'Manufacture and repair of pumps, compressors, taps and valves n.e.c.', 'Retail sale of household electrical appliances and equipment (e.g. vacuum cleaners, washing machines, refrigerators)', 'Manufacture of rubber automotive parts', 'Manufacture and repair of machinery for mining, quarrying and construction n.e.c.', 'Manufacture and repair of solar modules and panels', 'Manufacture and repair of separation/mixing equipment (e.g. filters, separators, mixers)']
# Final label: Manufacture and repair of tanks, reservoirs and containers of metal (e.g. metal cylinders, storage vessels and containers for compressed or liquefied gas), selected from Manufacture and repair of tanks, reservoirs and containers of metal (e.g. metal cylinders, storage vessels and containers for compressed or liquefied gas), Manufacture and repair of refrigerating, air-conditioning and ventilating machinery and equipment except household refrigerators
# Processing: data/fs/FAR EAST ORCHARD LIMITED 2022.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  - Investment holding
# - Hotel operations
# - Property investment
#
# The primary activity of the company is investment holding.
# Initial search:  ['Operating of serviced apartments', 'Bank/Financial holding companies (including insurance holding company)', 'Hotels', 'Collective portfolio investment funds with rental income', 'Letting of self-owned or leased real estate property except food courts, coffee shops and canteens (e.g. office/exhibition space, shopping mall, self-storage facilities)', 'Property fund management (including REIT management and direct property fund management)', 'Management consultancy services for hotels', 'Chalets', 'Casinos', 'Traditional/Long-only asset/Portfolio management']
# Initial search others:  ['Other holding companies', 'Residential (other than town councils), commercial and industrial real estate management', 'Renting and leasing of furniture, utensils and electronic equipment for household use', 'Short term accommodation activities other than hotels and chalets', 'Renting of industrial machinery and equipment', 'Corporate finance advisory services', 'Renting and leasing of other personal and household goods n.e.c. (excluding online marketplaces)', 'Recreation clubs (including country clubs)', 'Preservation of historical sites, buildings, artefacts and paintings, cultural villages and other related activities n.e.c.', 'Trustee, fiduciary and custody services firms (including nominee companies, trustees and REIT trustees)']
# Final label: Letting of self-owned or leased real estate property except food courts, coffee shops and canteens (e.g. office/exhibition space, shopping mall, self-storage facilities), selected from Letting of self-owned or leased real estate property except food courts, coffee shops and canteens (e.g. office/exhibition space, shopping mall, self-storage facilities), Investment holding
# Processing: data/fs/FU YU CORPORATION LIMITED 2022.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  - Manufacturing and sub-assembly of precision plastic parts and components
# - Fabrication of precision moulds and dies
#
# The primary activity of the company is manufacturing and sub-assembly of precision plastic parts and components, as well as fabrication of precision moulds and dies.
# Initial search:  ['Manufacture of plastic precision engineering parts', 'Manufacture of plastic sheet, film and articles thereof (e.g. polythene and polypropylene bags)', 'Manufacture of plastic tableware, household and kitchen ware (excluding disposable utensils)', 'Manufacture of plastic bottles, boxes and containers (except for household use)', 'Manufacture of derivatives and intermediates produced from basic building blocks (e.g. acetyls, acrylics, oxochemicals, styrene, phenolic, ethylene oxide derivatives and polymers)', 'Manufacture of plastic pipes and tubes', 'Manufacture of bearings (including disc and ball bearings)', 'Manufacture of discrete devices (e.g. diodes, light-emitting diodes, transistors and rectifiers)', 'Manufacture of implantables and artificial limbs (e.g. heart valves, stents, orthopaedic implants)', 'Manufacture of PVC files, holders and albums']
# Initial search others:  ['Manufacture of metal precision components', 'Manufacture and repair of plastic processing machinery', 'Manufacture of plastic products n.e.c. (except plastic footwear and toys)', 'Manufacture of epoxy moulding compounds and phenolic moulding compounds', 'Manufacture of rubber automotive parts', 'Manufacture and repair of polymer additive manufacturing (AM) equipment', 'Manufacture of ultrapure electronic chemicals, materials and laminates', 'Manufacture of industrial and mechanical rubber goods', 'Manufacture of laminboard, particle board and other panels and boards n.e.c.', 'Manufacture and repair of separation/mixing equipment (e.g. filters, separators, mixers)']
# Final label: Manufacture of plastic precision engineering parts, selected from Manufacture of plastic precision engineering parts, Manufacture of plastic products n.e.c. (except plastic footwear and toys)
# Processing: data/fs/GREAT EASTERN HOLDINGS LIMITED 2022.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  The activity of the company is not holding or 'investment holding'.
#
# The primary activity of the company is risk management and compliance.
# Initial search:  ['Bank/Financial holding companies (including insurance holding company)', 'Traditional/Long-only asset/Portfolio management', 'Single/Multiple family offices activities (e.g. managing investments and trusts for a single or multiple families)', 'Property fund management (including REIT management and direct property fund management)', 'Risk and damage evaluation (e.g. loss adjusting, claims adjusting)', 'Hedge fund management', 'Collective portfolio investment funds with rental income', 'Venture capital activities', 'Private equity firms', 'Accounting and auditing services (excluding online marketplaces)']
# Initial search others:  ['Other holding companies', 'Trustee, fiduciary and custody services firms (including nominee companies, trustees and REIT trustees)', 'Captive managers', 'Fund management activities n.e.c.', 'Activities auxiliary to fund management activities (e.g. independent fund administration firms)', 'Security dealings and commodity contracts brokerage activities n.e.c.', 'Corporate finance advisory services', 'Transaction/Payment processing services', 'Other financial service activities, except insurance and pension funding activities n.e.c.', 'Representative offices of foreign insurers and professional reinsurers']
# Final label: Other financial service activities, except insurance and pension funding activities n.e.c., selected from Risk and damage evaluation (e.g. loss adjusting, claims adjusting), Other financial service activities, except insurance and pension funding activities n.e.c.
# Processing: data/fs/HEETON HOLDINGS LIMITED 2022.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  - Property development
#
# - The activity of the company is property development, which involves the acquisition, development, and sale of real estate properties.
# Initial search:  ['Real estate developers', 'Operating of serviced apartments', 'Letting of self-owned or leased real estate property except food courts, coffee shops and canteens (e.g. office/exhibition space, shopping mall, self-storage facilities)', 'Real estate agencies and valuation services', 'Property fund management (including REIT management and direct property fund management)', 'Collective portfolio investment funds with rental income', 'Letting and operating of self-owned or leased food courts, coffee shops and canteens (with mainly rental income)', 'Town councils', 'Management of self-owned strata titled property (i.e. Management Corporation Strata Title)', 'Computer facilities management activities']
# Initial search others:  ['Residential (other than town councils), commercial and industrial real estate management', 'Other holding companies', 'Real estate activities on a fee or commission basis n.e.c. (excluding online marketplaces)', 'Production of advertisements, corporate videos and event videos', 'Renting and leasing of furniture, utensils and electronic equipment for household use', 'Manufacture of pesticides and other agro-chemical products (including insecticides, herbicides and disinfectants)', 'Building construction n.e.c.', 'Production of pre-cast components', 'Distribution of television programmes (e.g. dramas, variety shows and documentaries)', 'Translation services']
# Final label: Real estate developers, selected from Real estate developers, Residential (other than town councils), commercial and industrial real estate management
# Processing: data/fs/HIAP SENG ENGINEERING LTD 2023.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  - Provision of building construction, engineering, procurement, construction and plant tenance services for oil and gas and energy sectors.
# - Provision of process and industrial plant engineering and consultancy services.
#
# The primary activity of the company is the provision of engineering and construction services, including building construction, engineering, procurement, construction and plant tenance services for oil and gas and energy sectors, as well as process and industrial plant engineering and consultancy services.
# Initial search:  ['Engineering design and consultancy services supporting mining, oil and gas extraction and offshore exploration activities', 'General building engineering design and consultancy services', 'Service activities incidental to oil and gas extraction (excluding surveying and engineering design and consultancy services supporting mining, oil and gas extraction and offshore exploration activities)', 'Crude petroleum and natural gas production', 'Process and industrial plant engineering design and consultancy services', 'Manufacture and repair of oil rigs', 'Infrastructure engineering design and consultancy services', 'General contractors (building construction including major upgrading works)', 'Engineering design and consultancy services in energy management and clean energy systems', 'Environmental engineering design and consultancy services (except clean energy)']
# Initial search others:  ['Manufacture and repair of other oilfield and gasfield machinery and equipment (e.g. derricks, tool joints)', 'Manufacture and repair of machinery for mining, quarrying and construction n.e.c.', 'Manufacture and repair of separation/mixing equipment (e.g. filters, separators, mixers)', 'Engineering design and consultancy activities n.e.c.', 'Building and repairing of ships, tankers and other ocean-going vessels (including conversion of ships into off-shore structures)', 'Manufacture of refined petroleum products n.e.c.', 'Manufacture of water treatment, waste treatment and oilfield chemicals', 'Manufacture of non-structural pre-cast components (e.g. lightweight partitions, secondary roof slabs)', 'Manufacture of articles of concrete, cement and plaster n.e.c. (except precast concrete components)', 'Residential (other than town councils), commercial and industrial real estate management']
# Final label: Engineering design and consultancy activities n.e.c., selected from Process and industrial plant engineering design and consultancy services, Engineering design and consultancy activities n.e.c.
# Processing: data/fs/HOE LEONG CORPORATION LTD. 2022.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  - Designing, manufacturing and distribution of heavy equipment parts.
#
# - The company is primarily engaged in the designing, manufacturing and distribution of heavy equipment parts.
# Initial search:  ['Manufacture of bearings (including disc and ball bearings)', 'Wholesale of industrial machinery and equipment (e.g. industrial crane)', 'Manufacture of steel structural component', 'Renting of construction and civil engineering machinery and equipment', 'Manufacture and repair of gears, gearing and driving elements', 'Manufacture and repair of lifting and hoisting machinery except electrical', 'Manufacture and repair of construction machinery and parts', 'Manufacture and repair of marine engine', 'Manufacture and repair of engines and turbines except aircraft, vehicle, cycle and marine engines', 'Manufacture and repair of semiconductor foundry equipment']
# Initial search others:  ['Renting of industrial machinery and equipment', 'Manufacture of bolts, nuts, rivets, fasteners and screw machine products', 'Manufacture and repair of other oilfield and gasfield machinery and equipment (e.g. derricks, tool joints)', 'Manufacture of pipe fittings', 'Manufacture of metal precision components', 'Wholesale of industrial, construction and related machinery and equipment n.e.c.', 'Manufacture and repair of machinery for mining, quarrying and construction n.e.c.', 'Manufacture and repair of separation/mixing equipment (e.g. filters, separators, mixers)', 'Manufacture of rubber automotive parts', 'Manufacture and repair of water/waste water treatment equipment']
# Final label: Manufacture and repair of machinery for mining, quarrying and construction n.e.c., selected from Manufacture and repair of construction machinery and parts, Manufacture and repair of machinery for mining, quarrying and construction n.e.c.
# Processing: data/fs/HONG LEONG FINANCE LIMITED 2022.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  - The activity of the company is financing business.
# - The company provides loans, advances, and other financing services to businesses.
# Initial search:  ['Bank/Financial holding companies (including insurance holding company)', 'Debt collection services', 'Renting of office machinery and equipment', 'Financial leasing companies', 'Letting of self-owned or leased real estate property except food courts, coffee shops and canteens (e.g. office/exhibition space, shopping mall, self-storage facilities)', 'Renting and leasing of bicycles and inline/roller skates', 'Manufacture of bearings (including disc and ball bearings)', 'Operating of serviced apartments', 'Rental and leasing of cars with driver (excluding street-hail and ride-hail service providers)', 'Credit rating agencies']
# Initial search others:  ['Money-lending', 'Remittance services', 'Credit card services', 'Corporate finance advisory services', 'Factoring companies', 'Representative offices of foreign banks', 'Other financial service activities, except insurance and pension funding activities n.e.c.', 'Thrift and loan societies and credit associations', 'Other credit agencies n.e.c. (e.g. motor finance)', 'Transaction/Payment processing services']
# Final label: Money-lending, selected from Financial leasing companies, Money-lending
# Processing: data/fs/HOTEL GRAND CENTRAL LIMITED 2022.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  The activity of the company is owning, operating and managing hotels.
# Initial search:  ['Hotels', 'Operating of serviced apartments', 'Management consultancy services for hotels', 'Chalets', 'Letting of self-owned or leased real estate property except food courts, coffee shops and canteens (e.g. office/exhibition space, shopping mall, self-storage facilities)', 'Casinos', 'Collective portfolio investment funds with rental income', 'Property fund management (including REIT management and direct property fund management)', 'Letting and operating of self-owned or leased food courts, coffee shops and canteens (with mainly rental income)', 'Bank/Financial holding companies (including insurance holding company)']
# Initial search others:  ['Residential (other than town councils), commercial and industrial real estate management', 'Short term accommodation activities other than hotels and chalets', 'Other holding companies', 'Night clubs, discotheques, dance clubs and karaoke lounges', 'Recreation clubs (including country clubs)', 'Renting of industrial machinery and equipment', 'Renting and leasing of furniture, utensils and electronic equipment for household use', 'Renting and leasing of professional radio and television sets and sound reproducing and recording equipment', 'Amusement theme parks', 'Hostels and dormitories for students, workers and other individuals']
# Final label: Hotels, selected from Hotels, Short term accommodation activities other than hotels and chalets
# Processing: data/fs/HOTEL PROPERTIES LIMITED 2022.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  - The activity of the company is a holding company.
# - The company does not have any other primary activities besides holding or 'investment holding'.
# Processing: data/fs/HOTEL ROYAL LIMITED 2022.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  - The activity of the company is that of a hotelier.
# - The company owns and manages hotels, and provides hotel management services.
# Initial search:  ['Hotels', 'Operating of serviced apartments', 'Management consultancy services for hotels', 'Chalets', 'Letting of self-owned or leased real estate property except food courts, coffee shops and canteens (e.g. office/exhibition space, shopping mall, self-storage facilities)', 'Casinos', 'Rental and leasing of cars with driver (excluding street-hail and ride-hail service providers)', 'Letting and operating of self-owned or leased food courts, coffee shops and canteens (with mainly rental income)', 'Collective portfolio investment funds with rental income', 'Computer facilities management activities']
# Initial search others:  ['Residential (other than town councils), commercial and industrial real estate management', 'Short term accommodation activities other than hotels and chalets', 'Management consultancy services n.e.c.', 'Renting of industrial machinery and equipment', 'Night clubs, discotheques, dance clubs and karaoke lounges', 'Renting and leasing of professional radio and television sets and sound reproducing and recording equipment', 'Charitable and other supporting activities aimed at humanitarian work', 'Translation services', 'Preservation of historical sites, buildings, artefacts and paintings, cultural villages and other related activities n.e.c.', 'Manufacture of sanitary towels, toilet paper, paper towels, disposable diapers and related paper products']
# Final label: Hotels, selected from Hotels, Short term accommodation activities other than hotels and chalets
# Processing: data/fs/IFS CAPITAL LIMITED 2022.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  The activity of the company is the provision of commercial, alternative and structured finance businesses such as factoring services, working capital, asset based financing and the provision of alternative and structured financial solutions offered to clients to address either equity or debt capital requirements.
#
# Examples of goods and services: factoring services, working capital, asset based financing, alternative and structured financial solutions.
# Initial search:  ['Operating of serviced apartments', 'Money-changing services', 'Accounting and auditing services (excluding online marketplaces)', 'Letting of self-owned or leased real estate property except food courts, coffee shops and canteens (e.g. office/exhibition space, shopping mall, self-storage facilities)', 'Bank/Financial holding companies (including insurance holding company)', 'Private debt funds', 'Debt collection services', 'Manufacture of bearings (including disc and ball bearings)', 'Traditional/Long-only asset/Portfolio management', 'Financial leasing companies']
# ...
# Calling LLM to summarize pdf...
# Summary extracted:  - The primary activity of the company is the operation and provision of telecommunications services.
# - Examples of goods and services include mobile phone services, broadband internet, and cable television.
# Initial search:  ['Wired telecommunications network operation (including fixed-line, fibre optics, local/international PSTN and leased circuits)', 'Manufacture of wireless communications equipment (e.g. cellular phones)', 'Manufacture of telecommunications apparatus (e.g. PBX equipment, telephones except cellular)', 'Satellite telecommunications network operation', 'Wholesale of telecommunications equipment (excluding handphones)', 'Manufacture of telecommunications cables and wires', 'Manufacture of networking products (e.g. routers, switches)', 'Retail sale of handphones and peripheral equipment', 'Repair of communications equipment (e.g. mobile phones and fax machines)', 'Television programming and broadcasting (including cable, satellite, terrestrial television, internet and mobile)']
# Initial search others:  ['Mobile cellular and other wireless telecommunications network operation', 'Other telecommunications activities n.e.c. (e.g. provision of VoIP (Voice over Internet Protocol services))', 'Telecommunications resellers/third party telecommunications providers (including value-added network operators)', 'Internet access providers, include ISPs', 'Manufacture of communications equipment n.e.c.', 'Wholesale of handphones, handphone peripheral equipment and other telecommunications equipment', 'Renting and leasing of professional radio and television sets and sound reproducing and recording equipment', 'Remittance services', 'Renting and leasing of furniture, utensils and electronic equipment for household use', 'Movie, video, television and other programme distribution activities n.e.c.']
# Final label: Mobile cellular and other wireless telecommunications network operation, selected from Wired telecommunications network operation (including fixed-line, fibre optics, local/international PSTN and leased circuits), Mobile cellular and other wireless telecommunications network operation
# Processing: data/fs/SUNRIGHT LIMITED 2023.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  The activity of the company is investment holding and provision of management services.
# Processing: data/fs/SUNRISE SHARES HOLDINGS LTD. 2022.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  - Investment holding company
#
# - The company's primary activity is holding company or 'investment holding'.
# Processing: data/fs/TAI SIN ELECTRIC LIMITED 2023.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  - The activity of the company is that of cable and wire manufacturer and dealer in such products.
# - Examples of goods and services include cables, wires, and related products.
# Initial search:  ['Manufacture of electric power cables and wires', 'Manufacture of telecommunications cables and wires', 'Manufacture of wire and cable assemblies and harnesses', 'Manufacture of uninsulated wire (e.g. electronic component wire, bonding wire)', 'Manufacture of plastic cable ties', 'Manufacture of enamelled wires (used for winding of motors, transformers etc)', 'Manufacture of networking products (e.g. routers, switches)', 'Wholesale of electrical and wiring accessories', 'Wholesale of telecommunications equipment (excluding handphones)', 'Manufacture of wireless communications equipment (e.g. cellular phones)']
# Initial search others:  ['Manufacture of metal wire and cable products n.e.c.', 'Manufacture of other electronic and electric wires and cables n.e.c.', 'Manufacture of communications equipment n.e.c.', 'Wholesale of audio and video equipment except electrical and electronic components (e.g. radio and television sets, sound reproducing and recording equipment)', 'Wholesale of household electrical appliances and equipment (including household air-conditioners)', 'Manufacture of pipe fittings', 'Manufacture and repair of electric motors, generators, transformers and electricity distribution and control apparatus n.e.c. (e.g. busbar trunking)', 'Manufacture of laminboard, particle board and other panels and boards n.e.c.', 'Manufacture of plumbing, heating and related products (including parts) except electric', 'Manufacture of bolts, nuts, rivets, fasteners and screw machine products']
# Final label: Manufacture of electric power cables and wires, selected from Manufacture of electric power cables and wires, Manufacture of other electronic and electric wires and cables n.e.c.
# Processing: data/fs/TAT SENG PACKAGING GROUP LTD 2022.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  - Manufacturing and sales of corrugated paper products and other packaging products.
#
# - Examples of goods and services: corrugated boards, corrugated cartons, paper mould.
# Initial search:  ['Manufacture of corrugated paper and paperboard', 'Manufacture of containers and boxes of paper and paperboard', 'Wholesale of packaging materials', 'Wholesale of paper and paper products', 'Manufacture of plastic sheet, film and articles thereof (e.g. polythene and polypropylene bags)', 'Manufacture of plastic bottles, boxes and containers (except for household use)', 'Manufacture of pulp, paper and paperboard', 'Manufacture of plastic tableware, household and kitchen ware (excluding disposable utensils)', 'Wholesale of stationery', 'Manufacture of styrofoam and plastic disposable utensils']
# Initial search others:  ['Wholesale of paper, paper and cellophane products and stationery n.e.c.', 'Manufacture of laminboard, particle board and other panels and boards n.e.c.', 'Manufacture of wooden containers', 'Manufacture of paper cups, plates and utensils', 'Manufacture of other articles of paper and paperboard n.e.c. (e.g. papier mache, wallpaper)', 'Manufacture of cards, envelopes and stationery, unprinted', 'Manufacture and repair of packaging machinery', 'Manufacture of joss paper and other related ceremonial paper products (including effigies and other funeral paper goods and Chinese lanterns)', 'Manufacture of structural metal products n.e.c. (e.g. metal sections, corrugated sheets)', 'Manufacture of sanitary towels, toilet paper, paper towels, disposable diapers and related paper products']
# Final label: Manufacture of containers and boxes of paper and paperboard, selected from Manufacture of containers and boxes of paper and paperboard, Manufacture of other articles of paper and paperboard n.e.c. (e.g. papier mache, wallpaper)
# Processing: data/fs/TELECHOICE INTERNATIONAL LIMITED 2022.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  - Investment holding
#
# - Holding company
# Processing: data/fs/TT INTERNATIONAL LIMITED 2023.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  - Retail, trading and distribution of a wide range of furniture and furnishings, electrical and electronics products.
#
# - The primary activity of the company is retailing and distributing furniture, furnishings, electrical and electronics products.
# Initial search:  ['Manufacture of furniture and fixtures of wood (including upholstery)', 'Manufacture of furniture and fixtures primarily of metal', 'Department stores', 'Manufacture of plastic tableware, household and kitchen ware (excluding disposable utensils)', 'Supermarkets and Hypermarkets', 'Wholesale of motor vehicles except motorcycles and scooters', 'Furniture design services', 'Retail sale of audio and video equipment (e.g. radio and television sets, sound reproducing and recording equipment)', 'Letting of self-owned or leased real estate property except food courts, coffee shops and canteens (e.g. office/exhibition space, shopping mall, self-storage facilities)', 'Retail sale of antiques and works of art']
# Initial search others:  ['Retail sale of electrical household appliances, furniture, lighting equipment and other household articles n.e.c.', 'Retail sale of furniture (including mattresses, cushions)', 'Wholesale of household electrical appliances and equipment (including household air-conditioners)', 'Wholesale of furniture, home furnishings and other household equipment n.e.c.', 'Wholesale of audio and video equipment except electrical and electronic components (e.g. radio and television sets, sound reproducing and recording equipment)', 'Retail sale of furnishings (e.g. curtains, carpets, pillow cases)', 'Retail sale of household electrical appliances and equipment (e.g. vacuum cleaners, washing machines, refrigerators)', 'Wholesale of furniture (including mattresses, cushions)', 'Renting and leasing of furniture, utensils and electronic equipment for household use', 'Retail sale of lighting and lighting accessories']
# Final label: Retail sale of electrical household appliances, furniture, lighting equipment and other household articles n.e.c., selected from Department stores, Retail sale of electrical household appliances, furniture, lighting equipment and other household articles n.e.c.
# Processing: data/fs/UNITED OVERSEAS INSURANCE LIMITED 2022.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  - The activity of the company is the underwriting of general insurance business and reinsurance.
# - General insurance covers a broad spectrum of classes of insurance, among which are fire, marine, motor, engineering, general accident and liability business.
# Initial search:  ['General insurance (except marine and import, export & credit insurance)', 'General reinsurance', 'Import, export and credit insurance', 'Marine insurance', 'Captive insurance', 'Life insurance', 'Life reinsurance', 'Risk and damage evaluation (e.g. loss adjusting, claims adjusting)', 'Insurance brokers', 'Bank/Financial holding companies (including insurance holding company)']
# Initial search others:  ['Representative offices of foreign insurers and professional reinsurers', 'Other activities auxiliary to insurance and pension funding n.e.c. (e.g. activities of actuaries)', 'Other financial service activities, except insurance and pension funding activities n.e.c.', 'Other related services (e.g. arranging for sale of natural gas)', 'Remittance services', 'Factoring companies', 'Representative offices of foreign banks', 'Manufacture and repair of refrigerating, air-conditioning and ventilating machinery and equipment except household refrigerators', 'Corporate finance advisory services', 'Other holding companies']
# Final label: General insurance (except marine and import, export & credit insurance), selected from General insurance (except marine and import, export & credit insurance), Representative offices of foreign insurers and professional reinsurers
# Processing: data/fs/VENTURE CORPORATION LIMITED 2022.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  - The primary activity of the company is to provide manufacturing, product design and development, engineering and supply-chain management services.
# - Examples of goods and services include electronic components, semiconductors, and printed circuit boards.
# Initial search:  ['Assembly and testing of semiconductors', 'Manufacture of discrete devices (e.g. diodes, light-emitting diodes, transistors and rectifiers)', 'Semiconductor wafer fabrication', 'Manufacture and repair of semiconductor assembly and testing equipment (including computer burn-in system)', 'Manufacture and repair of semiconductor foundry equipment', 'Manufacture of consumer electronics', 'Wholesale of electronic components', 'Manufacture of disk drives (including CD-ROM drives, DVD-ROM drives, optical drives, flash drives, tape drives, solid state drives, storage subsystems)', 'Manufacture of computers and data processing equipment except computer peripheral equipment', 'Manufacture of bonding tools']
# Initial search others:  ['Manufacture of printed circuit boards with electronic parts', 'Manufacture of other electronic components and boards n.e.c.', 'Manufacture of printed circuit boards without electronic parts', 'Manufacture of semiconductor devices n.e.c.', 'Manufacture of capacitors', 'Manufacture of electronic connectors', 'Manufacture of piezo-electric devices (e.g. quartz crystals, quartz crystal filters, delay lines)', 'Manufacture of ultrapure electronic chemicals, materials and laminates', 'Manufacture of metal precision components', 'Manufacture of electronic display devices except light emitting diodes']
# Final label: Manufacture of printed circuit boards with electronic parts, selected from Assembly and testing of semiconductors, Manufacture of printed circuit boards with electronic parts
# Processing: data/fs/VICOM LTD 2022.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  - Investment holding company
#
# - The company's primary activity is solely holding or 'investment holding'.
# Processing: data/fs/VICPLAS INTERNATIONAL LTD 2023.pdf
# Calling LLM to summarize pdf...
# Summary extracted:  - The activity of the company is investment holding.
# - The company does not have any other primary activities besides investment holding.
# Accuracy: 0.31
#                               Company  SSIC Code  \
# 0                ABR HOLDINGS LIMITED      47219
# 1     ABUNDANCE INTERNATIONAL LIMITED      46649
# 2                   ABUNDANTE LIMITED      23940
# 3                      ACCRELIST LTD.      46900
# 4            ACESIAN PARTNERS LIMITED      41009
# ..                                ...        ...
# 95           TT INTERNATIONAL LIMITED      46900
# 96  UNITED OVERSEAS INSURANCE LIMITED      65124
# 97        VENTURE CORPORATION LIMITED      26201
# 98                          VICOM LTD      95303
# 99          VICPLAS INTERNATIONAL LTD      64202
#
#                                    Company  \
# 0                ABR HOLDINGS LIMITED 2022
# 1     ABUNDANCE INTERNATIONAL LIMITED 2022
# 2                   ABUNDANTE LIMITED 2023
# 3                            ACCRELIST LTD
# 4            ACESIAN PARTNERS LIMITED 2022
# ..                                     ...
# 95           TT INTERNATIONAL LIMITED 2023
# 96  UNITED OVERSEAS INSURANCE LIMITED 2022
# 97        VENTURE CORPORATION LIMITED 2022
# 98                          VICOM LTD 2022
# 99          VICPLAS INTERNATIONAL LTD 2023
#
#                                SSIC Title (Predicted) SSIC Code (Predicted)  \
# 0                            Manufacture of ice-cream                 10503
# 1   Commercial printing (e.g. printing of brochure...                 18113
# 2                             Other holding companies                 64202
# 3                             Other holding companies                 64202
# 4   Manufacture and repair of refrigerating, air-c...                 28191
# ..                                                ...                   ...
# 95  Retail sale of electrical household appliances...                 47539
# 96  General insurance (except marine and import, e...                 65124
# 97  Manufacture of printed circuit boards with ele...                 26123
# 98                            Other holding companies                 64202
# 99                            Other holding companies                 64202
#
#                                           Explanation Model Score
# 0   - The principal activities of the Company are ...        None
# 1   - The principal activities of the Company are ...        None
# 2   - The principal activities of the Company are ...        None
# 3   - The principal activities of the Company is i...        None
# 4   - The primary activities of the Group consist ...        None
# ..                                                ...         ...
# 95  - The primary activities of the Company are th...        None
# 96  - The Company’s principal activities are the u...        None
# 97  - The principal activities of the Company are ...        None
# 98  - The company's primary activity is solely hol...        None
# 99  - The principal activity of the Company is tha...        None
#
# [100 rows x 7 columns]

# %% [markdown]
# # Gradio Application

# %%
def load_pdf(file_content):
    #file_content = file_content.read()
    doc = fitz.open("pdf", file_content)
    concatenated_text = []
    important_text = ""
    length = 0
    num_pages = 0
    exclude_strings = [
        'auditor',
        "director",
        "accounting policies",
        "corporate governance",
        "lease liabilities",
        "sustainability",
        "consolidated statement of cash flows",
        "financial risk",
        "dividend"
        ]
    for page_num in range(doc.page_count):
        if page_num >=2:
            page = doc.load_page(page_num)
            page_text = page.get_text()
            num_pages += 1
            # Check if any of the exclude_strings are present on the page
            if (re.search(re.compile(r'note(s)?\s*to\s*(the)?\s*financial\s*statement(s)?', re.IGNORECASE), page_text)) and ("activit" in page_text.lower()):
                important_text += page_text
                continue
            if any(exclude_str in page_text.lower() for exclude_str in exclude_strings):
                if "activit" not in page_text.lower():
                    continue  # Skip this page if any exclude_string is found
            concatenated_text.append(page_text)
    if len(important_text) >= 8000:
        important_text = important_text[:8000]
    return '\n'.join(concatenated_text), important_text


def gradio_pipeline(file_path):
    bucket_name = "acra-ssic-classification"
    fileloader = FileLoader(bucket_name)
    config = fileloader.read_yaml_from_gcs("config.yaml")

    project_id = config["project_id"]
    #others_score_threshold = config["others_score_threshold"]
    text_embedding_model_name =  config["text_embedding_model_name"]
    classifier_model_name = config["classifier_model_name"]
    summarizer_model_name = config["summarizer_model_name"]
    google_model_name = config["google_model_name"]

    batch_size = config["batch_size"]

    # Load directories
    model_location = config["dir"]["model_location"]
    tokenizer_location = config["dir"]["tokenizer_location"]
    ssic_df_fp = config["dir"]["ssic_df_fp"]
    l3_list_fp = config["dir"]["l3_list_fp"]
    l3_list_others_fp = config["dir"]["l3_list_others_fp"]
    activity_embedding_fp = config["dir"]["activity_embedding_fp"]
    l2_l3_embeddings_fp = config["dir"]["l2_l3_embeddings_fp"]
    l2_l3_embeddings_others_fp = config["dir"]["l2_l3_embeddings_others_fp"]
    fs_dir = config["dir"]["fs_dir"]
    output_fp = config["dir"]["output_fp"]
    label_fp = config["dir"]["label_fp"]
    evaluator_fp = config["dir"]["evaluator_fp"]

    # Load artifacts
    ssic_df = fileloader.load_df_from_gcs(ssic_df_fp, header = config['columns']["header_row"])
    l3_desc_list = fileloader.load_json_from_gcs(l3_list_fp)
    l3_desc_list_others = fileloader.load_json_from_gcs(l3_list_others_fp)
    l2_l3_embeddings = fileloader.load_embeddings(l2_l3_embeddings_fp, text_embedding_model_name)
    l2_l3_embeddings_others = fileloader.load_embeddings(l2_l3_embeddings_others_fp, text_embedding_model_name)
    activity_embedding = fileloader.load_embeddings(activity_embedding_fp, text_embedding_model_name)
    label = fileloader.load_csv_from_gcs(label_fp)

    # Load artifacts
    text_embedder = TextEmbedder(text_embedding_model_name,
                                      from_local = True,
                                      project_id=project_id,
                                      bucket_name=bucket_name,
                                      model_location = model_location,
                                      tokenizer_location = tokenizer_location)

    fileloader = FileLoader(bucket_name)
    config = fileloader.read_yaml_from_gcs("config.yaml")

    project_id = config["project_id"]
    #others_score_threshold = config["others_score_threshold"]
    text_embedding_model_name =  config["text_embedding_model_name"]
    classifier_model_name = config["classifier_model_name"]
    summarizer_model_name = config["summarizer_model_name"]
    google_model_name = config["google_model_name"]

    batch_size = config["batch_size"]

    # Load directories
    model_location = config["dir"]["model_location"]
    tokenizer_location = config["dir"]["tokenizer_location"]
    ssic_df_fp = config["dir"]["ssic_df_fp"]
    l3_list_fp = config["dir"]["l3_list_fp"]
    l3_list_others_fp = config["dir"]["l3_list_others_fp"]
    activity_embedding_fp = config["dir"]["activity_embedding_fp"]
    l2_l3_embeddings_fp = config["dir"]["l2_l3_embeddings_fp"]
    l2_l3_embeddings_others_fp = config["dir"]["l2_l3_embeddings_others_fp"]
    fs_dir = config["dir"]["fs_dir"]
    output_fp = config["dir"]["output_fp"]
    label_fp = config["dir"]["label_fp"]
    evaluator_fp = config["dir"]["evaluator_fp"]


    ssic_df = fileloader.load_df_from_gcs(ssic_df_fp, header = config['columns']["header_row"])
    l3_desc_list = fileloader.load_json_from_gcs(l3_list_fp)
    l3_desc_list_others = fileloader.load_json_from_gcs(l3_list_others_fp)
    l2_l3_embeddings = fileloader.load_embeddings(l2_l3_embeddings_fp, text_embedding_model_name)
    l2_l3_embeddings_others = fileloader.load_embeddings(l2_l3_embeddings_others_fp, text_embedding_model_name)
    activity_embedding = fileloader.load_embeddings(activity_embedding_fp, text_embedding_model_name)
    label = fileloader.load_csv_from_gcs(label_fp)

    summarizer = FsSummarizer(
        project_id,
        summarizer_model_name,
        max_decode_steps = 256,
        temperature = 0.0,
        top_p = 1.0,
        top_k = 10,
        chunk_size = 1000,
        chunk_overlap = 50,
        text_embedder= text_embedder,
        activity_embedding= activity_embedding,
        k_sim = 5,
        location= "asia-southeast1"
        )

    classifier_google = Classifier(project_id,
                            google_model_name,
                            max_decode_steps = 256,
                            temperature =0.0,
                            top_p = 1.0,
                            top_k = 10,
                            location= "asia-southeast1"
                            )

    classifier = Classifier(project_id,
                            classifier_model_name,
                            max_decode_steps = 256,
                            temperature =0.0,
                            top_p = 1.0,
                            top_k = 10,
                            location= "asia-southeast1"
                            )

    ssic_classifier = SSICClassifier(
        classifier_google,
        classifier,
        ssic_df,
        text_embedder,
        #others_score_threshold,
        l3_desc_list,
        l3_desc_list_others,
        l2_l3_embeddings,
        l2_l3_embeddings_others,
        config
        )
    fs, important_text = load_pdf(file_path)

    relevant_chunks, summarized_desc = summarizer.run_summarizer(fs, important_text, 10)
    summary_explanation = summarizer.explain(summarized_desc, relevant_chunks)

    print("Summary extracted: ", summarized_desc)
    ## Perform Classification
    ssic_code, ssic_label, model_score = ssic_classifier.classify(summarized_desc)
    if model_score:
        return str(ssic_code) + " - " + ssic_label + ". Score: "+ str(np.round(model_score,2)) +"\nExplanation: " + summary_explanation
    else:
        return str(ssic_code) + " - " + ssic_label +". Explanation: " + summary_explanation

# %%
# Gradio interface
import typing_extensions
import gradio as gr
iface = gr.Interface(
    fn=gradio_pipeline,
    inputs=gr.File(type="binary", label="Upload One PDF File"),
    outputs="text",
    live=True,
    title="SSIC Code Classification",
    description=""
)

# Launch the Gradio interface
iface.launch()
# Out:
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://85c2b42a9215485747.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://85c2b42a9215485747.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
