# %% [markdown]
# # Gemini Code

# %%
import vertexai
from vertexai.preview.generative_models import GenerativeModel, ChatSession
from vertexai.generative_models import (
    GenerativeModel,
    HarmCategory,
    HarmBlockThreshold,
    Part,
    SafetySetting,
)
project_id = "rising-precinct-429608-h9"
location = "asia-southeast1"
vertexai.init(project=project_id, location=location)

safety_config = {
    HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: HarmBlockThreshold.BLOCK_NONE,
    HarmCategory.HARM_CATEGORY_HARASSMENT: HarmBlockThreshold.BLOCK_NONE,
    HarmCategory.HARM_CATEGORY_HATE_SPEECH: HarmBlockThreshold.BLOCK_NONE,
    HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: HarmBlockThreshold.BLOCK_NONE,
}

model = GenerativeModel("gemini-1.5-pro")
chat = model.start_chat(response_validation=False)

def get_chat_response(chat: ChatSession, prompt: str):
    response = chat.send_message(prompt, safety_settings=safety_config,)
    return response.text

prompt = "Hello"
print(get_chat_response(chat, prompt))
# Out:
# Hello! 👋
#
# What can I do for you today? 😊

# %%
import json

output_path = 'medusa_response.json'

with open(output_path, "r") as outfile:
    medusa = json.load(outfile)
print(len(medusa))
# Out:
# 304

# %%
import json

output_path = 'vicuna_response.json'

with open(output_path, "r") as outfile:
    vicuna = json.load(outfile)
print(len(vicuna))
# Out:
# 304

# %%
import json

output_path = 'hansard_answered_questions_llama3_formatted_test.json'

with open(output_path, "r") as outfile:
    ground_truth_qa = json.load(outfile)
print(len(ground_truth_qa))
# Out:
# 304

# %%
ground_truth = []
for qa in ground_truth_qa:
  answer = qa['conversations'][-1]
  if answer['from'] == 'gpt':
    ground_truth.append(answer['value'])
  else:
    ground_truth.append('')
    print(answer)
print(len(ground_truth))
# Out:
# {'from': 'human', 'value': 'Question:Mr Louis Ng Kok Kwang asked the Minister for Sustainability and the Environment in assessing ventilation in migrant worker dormitories using carbon dioxide measurements as a proxy (a) whether the Ministry will consider taking measurements in separate locations, including workers’ sleeping rooms; and (b) whether the Ministry will include all types of dormitories, such as Construction Temporary Quarters and Factory-Converted Dormitories.\n\nSupporting points: **Title: Extension of Ventilation Assessment to All Dormitory Types and Locations**\n\n**Introduction**\n\nIn response to growing concerns over indoor air quality and its potential impacts on the health and well-being of dormitory residents, the Ministry has decided to extend its ventilation assessment to encompass all types of dormitories and locations. This extension is a proactive measure aimed at ensuring the living conditions within these spaces are conducive to the health of the occupants, particularly in light of the ongoing global health challenges.\n\n**Background**\n\nIndoor air quality has emerged as a significant public health concern, particularly in densely populated living spaces such as dormitories. Poor ventilation can lead to the accumulation of carbon dioxide (CO₂) and other pollutants, which can adversely affect respiratory health and overall well-being. Recognizing the critical importance of this issue, the Ministry has decided to undertake a comprehensive assessment of ventilation systems across all dormitory types and locations.\n\n**Assessment Strategy**\n\n1. **Carbon Dioxide Measurements in Workers’ Sleeping Rooms:**\n   To obtain a detailed understanding of the air quality in dormitories, the Ministry will conduct CO₂ measurements in various locations, with a particular focus on workers’ sleeping rooms. Elevated levels of CO₂ can indicate inadequate ventilation, which can lead to discomfort and health issues such as headaches, dizziness, and fatigue. By monitoring CO₂ levels in these critical areas, the Ministry aims to identify and address potential ventilation inadequacies.\n\n2. **Inclusion of All Dormitory Types:**\n   The assessment will not be limited to a specific type of dormitory. Instead, it will encompass a wide range of dormitory types to ensure a comprehensive evaluation. These include:\n\n   - **Construction Temporary Quarters (CTQs):**\n     These dormitories are often used to house construction workers on a temporary basis. Given the transient nature of the residents and the often makeshift nature of these accommodations, it is crucial to ensure that ventilation systems are adequate to maintain acceptable indoor air quality levels.\n\n   - **Factory-Converted Dormitories (FCDs):**\n     These dormitories are typically converted from industrial spaces to residential use. Such conversions can present unique ventilation challenges due to the original design and purpose of the buildings. The Ministry will assess these spaces to ensure that they meet the necessary standards for safe and healthy living environments.\n\n3. **Geographical Scope:**\n   The assessment will be conducted across various locations to ensure a comprehensive understanding of ventilation conditions in dormitories nationwide. This geographical diversity will help the Ministry identify any region-specific issues and develop tailored solutions.\n\n**Methodology**\n\nThe Ministry will employ a multi-faceted approach to the assessment, including:\n\n- **On-Site Inspections:**\n  Teams will visit dormitories to conduct physical inspections of ventilation systems, ensuring they are functioning correctly and efficiently.\n\n- **Monitoring and Data Collection:**\n  CO₂ sensors and other air quality monitoring devices will be installed in key areas, including sleeping rooms, common areas, and kitchens. Data will be collected continuously over a specified period to capture variations in air quality.\n\n- **Resident Feedback:**\n  Surveys a ...
# {'from': 'human', 'value': "Question:Mr Derrick Goh asked the Minister for Education as building of the MOE Kindergarten at North View Primary School has been completed in 2022, when can Nee Soon Link residents resume booking and using the school’s indoor sports hall for activities under the ActiveSG Dual-Use Scheme.\n\nSupporting points: **Resumption of Booking of North View Primary School's Indoor Sports Hall under Dual-Use Scheme**\n\n**Introduction**\n\nThis report aims to provide a comprehensive update on the resumption of booking and use of the indoor sports hall at North View Primary School under the ActiveSG Dual-Use Scheme. The facility will be available for public booking starting in the third quarter of 2023. This initiative is a significant step towards promoting community engagement and enhancing public access to quality sports facilities.\n\n**Background**\n\nNorth View Primary School has been a crucial participant in the ActiveSG Dual-Use Scheme, which allows school sports facilities to be utilized by the community outside of school hours. The scheme aims to maximize the use of existing infrastructure, promote active lifestyles, and foster stronger community bonds. Due to various operational challenges, including the recent global pandemic, the use of the indoor sports hall was temporarily suspended. However, with the easing of restrictions and improved safety protocols, we are now prepared to resume this valuable community service.\n\n**Resumption Details**\n\n1. **Timeline**\n   Booking and use of the indoor sports hall will officially resume in the third quarter of 2023. The exact date will be communicated through ActiveSG’s official channels and the North View Primary School’s communication platforms.\n\n2. **Booking Process**\n   The booking process will remain streamlined and accessible through the ActiveSG app and website. Users can log in to check availability, book slots, and make payments online. This digital approach ensures a hassle-free and efficient booking experience for all users.\n\n3. **Operational Hours**\n   The indoor sports hall will be available for community use from 6:00 PM to 10:00 PM on weekdays and from 8:00 AM to 10:00 PM on weekends and public holidays. These hours have been carefully selected to avoid conflicts with school activities while providing ample time for community use.\n\n4. **Safety Measures**\n   In light of the ongoing need for health and safety precautions, several measures will be in place:\n   - Mandatory mask-wearing in common areas.\n   - Hand sanitizing stations at entry and exit points.\n   - Regular cleaning and disinfection of the facility.\n   - Capacity limitations to ensure social distancing.\n\n5. **Programs and Activities**\n   A variety of programs and activities will be available, catering to different age groups and interests. These include basketball, badminton, volleyball, and group fitness classes. Collaboration with local sports clubs and community groups will further enrich the range of activities offered.\n\n**Community Benefits**\n\n1. **Promoting Active Lifestyles**\n   The resumption of the indoor sports hall’s use will encourage residents to engage in physical activities, contributing to better health and well-being.\n\n2. **Strengthening Community Bonds**\n   By providing a shared space for sports and recreation, the initiative will foster stronger community ties and a sense of belonging among residents.\n\n3. **Optimizing Resource Utilization**\n   The dual-use scheme exemplifies efficient use of public resources, ensuring that the school’s facilities benefit a broader audience beyond the student population.\n\n**Challenges and Mitigation Strategies**\n\n1. **Managing Demand**\n   High demand for the facility may lead to booking difficulties. To mitigate this, we will implement a fair usage policy, limiting the number of bookings per individual or group.\n\n2. **Maintaining Safety and Hygiene**\n   Ensuring adherence to safety protocols is  ...
# {'from': 'human', 'value': "Question:Mr Sitoh Yih Pin asked the Minister for Transport (a) whether LTA has any concerns on the bicycle-sharing market in view of the exit of SG Bike which leaves only Anywheel and HelloRide as the remaining operators; and (b) whether this development will adversely affect Singaporean users of such services in terms of price and experience.\n\nSupporting points: ### Impact of SG Bike's Exit on Bike Users\n\n#### Introduction\nThe recent exit of SG Bike from the bicycle-sharing market has raised concerns among users and stakeholders alike. As a public servant tasked with monitoring and reporting on this sector, I have conducted a thorough analysis to assess the impact of this development on bike users. This report outlines the current state of the bicycle-sharing market, evaluates the implications of SG Bike's exit, and highlights the measures taken by the Land Transport Authority (LTA) to ensure a seamless transition for users.\n\n#### Current Market Landscape\nPrior to its exit, SG Bike was a significant player in the bicycle-sharing ecosystem in Singapore. With its departure, the market has been reduced to two primary operators: Anywheel and HelloRide. This reduction in competition has understandably caused concerns regarding potential monopolistic behavior, pricing, and service quality.\n\nThe LTA is acutely aware of these concerns and is actively monitoring the bicycle-sharing market to ensure that it remains competitive and user-friendly. The authority is committed to maintaining a balanced market where users can continue to enjoy affordable and reliable bike-sharing services.\n\n#### Regulatory Oversight\nIn light of SG Bike's exit, the LTA has intensified its efforts to ensure that the remaining operators adhere strictly to established regulations. These regulations are designed to maintain high standards of service quality, safety, and accessibility for all users.\n\n1. **Service Quality**: The LTA is conducting regular inspections and audits of Anywheel and HelloRide to ensure that their fleets are well-maintained and that bikes are readily available in high-demand areas. Operators are required to meet specific performance metrics, including bike availability, condition, and customer service response times.\n\n2. **Safety**: Safety remains a top priority. The LTA is working closely with Anywheel and HelloRide to ensure that all bicycles meet safety standards. This includes regular maintenance checks, proper lighting for night use, and ensuring that bicycles are equipped with functional brakes and bells.\n\n3. **Accessibility**: To ensure that bicycle-sharing services remain accessible to a broad user base, the LTA is enforcing regulations that require operators to distribute bicycles evenly across different neighborhoods, including underserved areas. This helps to prevent clustering in high-demand zones and ensures equitable access for all residents.\n\n#### Mitigating User Impact\nOne of the primary concerns following SG Bike's exit is the potential impact on users in terms of pricing and overall experience. The LTA has taken several proactive steps to mitigate these impacts:\n\n1. **Price Monitoring**: The LTA is closely monitoring the pricing strategies of Anywheel and HelloRide to ensure that prices remain fair and competitive. Any attempts to unfairly increase prices in the absence of SG Bike will be addressed promptly. Additionally, the LTA is exploring potential subsidies or incentives to keep bike-sharing affordable for all users.\n\n2. **User Experience**: The LTA is collaborating with the remaining operators to enhance the overall user experience. This includes improving app interfaces, offering better customer support, and ensuring that bicycles are available at convenient locations. Feedback from users is being actively solicited and incorporated into service improvements.\n\n3. **Alternative Solutions**: In the event of any service disruptions or gaps in coverage, the LTA is ...
# 304

# %%
def get_preference(medusa, other):
  all_responses = []
  for i in range(len(medusa)):
    medusa_qa = medusa[i]
    other_a = other[i]
    medusa_q = "#Answer:".join(medusa_qa.split["#Answer:"][:-1])
    medusa_a = medusa_qa.split["#Answer:"][-1]
    prompt = f"""Tell me which answer you prefer to the question below. Strictly reply 1 or 2 only without explanation or preamble.
    Question: {medusa_q}

    Answer 1: {medusa_a}
    Answer 2: {other_a}
    """
    response = get_chat_response(chat, prompt)
  return all_responses

# %%
#

# %% [markdown]
# # RAGAS

# %%
'''
def context_relevance(questions):
  all_responses = []
  for q in questions:

    prompt = f"""The following is a question, followed by Supporting points, and then the answer. Only consider the lsat question-answer pair.
    {q}
    List all the independent claims in the supporting points, strictly separated by line breaks only, without explanation or preamble. """
    response1 = get_chat_response(chat, prompt)

    prompt = f"""The following is a question, followed by Supporting points, and then the answer. Only consider the lsat question-answer pair.
    {q}

    These are the independent claims in the supporting point: {response1}

    List the number of independent claims in the supporting point which is relevant to the question, separated by line breaks, without explanation or preamble."""
    response2 = get_chat_response(chat, prompt)
    num_response1 = len(response1.split("\n"))
    num_response2 = len(response2.split("\n"))
    all_responses.append([num_response1, num_response2])
  return all_responses
'''

# %%
import time
def answer_correctness(questions, ground_truth):
  all_responses = []
  for i in range(len(questions)):
    pred = questions[i].split("# Answer:")[-1]
    gt = ground_truth[i]
    if (len(gt)>0) and (len(pred)> 1):
      prompt = f""" Determine if the following statement is correct given the ground truth. Respond striclty with 1 (corect) or 0 (incorrect).
      Statement: {pred}
      Ground Truth: {gt}

      The output must be 0 or 1 without explanation.
      """
      try:
        response = get_chat_response(chat, prompt)
      except:
        time.sleep(0.1)
        try:
          response = get_chat_response(chat, prompt)
        except:
          time.sleep(60)
          response = get_chat_response(chat, prompt)
      if response[0] in ["0", "1"]:
        response = response[0]
      all_responses.append(response.strip())

    else:
      all_responses.append("")
  return all_responses

# %%
medusa_ans_corr = answer_correctness(medusa , ground_truth)
medusa_ac = [int(a) for a in medusa_ans_corr if len(a)==1]
import numpy as np
np.mean(medusa_ac) #0.80

# %%
vicuna_ans_corr = answer_correctness(vicuna , ground_truth)
vicuna_ac = [int(a) for  a in vicuna_ans_corr if len(a)==1]
print(np.mean(vicuna_ac)) #0.47
# Out:
# 0.4717607973421927

# %%
from vertexai.preview.language_models import TextEmbeddingModel
model = TextEmbeddingModel.from_pretrained("text-embedding-004")

def get_embeddings(text):
  embeddings = model.get_embeddings([text],)

  for embedding in embeddings:
    vector = embedding.values
  return vector

# %%
import numpy as np
import time
def answer_sim(questions, ground_truth):
  all_sim = []
  for i in range(len(questions)):
    pred = questions[i].split("# Answer:")[-1]
    gt = ground_truth[i]
    if (len(gt)>0) and (len(pred)> 10):
      embedding1 = np.array(get_embeddings(pred))
      embedding2 = np.array(get_embeddings(gt))
      similarity = np.dot(embedding1, embedding2) / (np.linalg.norm(embedding1) * np.linalg.norm(embedding2))
      all_sim.append(similarity)
      time.sleep(0.1)

  return all_sim

# %%
medusa_sim = answer_sim(medusa , ground_truth)
np.mean(medusa_sim)
# Out:
# [0.9655236357600216, 0.9806240186432382, 0.8944921415080447]

# %%
medusa_sim

# %%
from tqdm import tqdm
import time
def faithfulness(questions):
  all_responses = []
  for q in tqdm(questions):

    prompt = f"""The following is a question, followed by Supporting points, and then the answer. Only consider the lsat question-answer pair.
    {q[:150000]}
    List all the independent claims in the answer, strictly separated by line breaks only, without explanation or preamble. """
    try:
      response1 = get_chat_response(chat, prompt)
      time.sleep(0.5)
    except:
      time.sleep(60)
      response1 = get_chat_response(chat, prompt)

    prompt = f"""The following is a question, followed by Supporting points, and then the answer. Only consider the lsat question-answer pair.
    {q[:1500000]}

    These are the independent claims in the answers: {response1[:100000]}

    List the points from the above which is relevant to the supporting points, separated by line breaks, without explanation or preamble."""
    try:
      response2 = get_chat_response(chat, prompt)
      time.sleep(0.5)
    except:
      time.sleep(60)
      response2 = get_chat_response(chat, prompt)

    num_response1 = len(response1.split("\n"))
    num_response2 = len(response2.split("\n"))
    if num_response2> num_response1:
      num_response2 = num_response1
    all_responses.append([num_response1, num_response2])
  return all_responses

# %%
f_medusa = faithfulness(medusa)
faith_medusa = [int(b)/int(a) for a,b in f_medusa ]
import numpy as np
np.mean(faith_medusa)
# Out:
# 100%|██████████| 304/304 [1:54:44<00:00, 22.65s/it]
# 0.8575170169742539

# %%
f_vicuna= faithfulness(vicuna)
faith_vicuna = [int(b)/int(a) for a,b in f_vicuna ]
import numpy as np
np.mean(faith_vicuna)
# Out:
# 100%|██████████| 304/304 [5:33:33<00:00, 65.84s/it]
# 0.6961408360895768

# %%
from tqdm import tqdm

def answer_relevance(questions):
  all_responses = []
  for q in tqdm(questions):

    prompt = f"""The following is a question, followed by Supporting points, and then the answer. Only consider the lsat question-answer pair.
    {q[:1500000]}
    List all the independent claims in the answer, strictly separated by line breaks only, without explanation or preamble. """
    try:
      response1 = get_chat_response(chat, prompt)
      time.sleep(0.1)
    except:
      time.sleep(120)
      response1 = get_chat_response(chat, prompt)
    prompt = f"""The following is a question.
    {q.split("Supporting Points:")[0][:1500000]}

    These are the independent claims in the answer:
    {response1[:100000]}

    List the claims above which are relevant to the question, separated by line breaks, without explanation or preamble."""
    try:
      response2 = get_chat_response(chat, prompt)
      time.sleep(0.1)
    except:
      time.sleep(120)
      response2 = get_chat_response(chat, prompt)

    num_response1 = len(response1.split("\n"))
    num_response2 = len(response2.split("\n"))
    if num_response1 < num_response2:
      num_response2 = num_response1
    all_responses.append([num_response1, num_response2])
  return all_responses

# %%
ar_medusa = answer_relevance(medusa)
rel_medusa = [int(b)/int(a) for a,b in ar_medusa ]
import numpy as np
np.mean(rel_medusa)

# %%
ar_vicuna = answer_relevance(vicuna)
rel_vicuna = [int(b)/int(a) for a,b in ar_vicuna ]
import numpy as np
np.mean(rel_vicuna)
